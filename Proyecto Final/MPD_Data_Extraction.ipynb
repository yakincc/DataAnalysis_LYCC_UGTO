# %% [markdown]
# # MIllion Playlists Dataset Data Extraction
# This Notebook is used to extract the required Data from the Million Playlist Dataset created by Spotify.
#
# ---

# %% [markdown]
# ### Importing the Libraries needed for the data extraction

# %%
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import spotipy
import config
import math
import json
import os

# %% [markdown]
# ### Spotify's Authentication
# We must first parse API credentials to Spotipy's client manager, in order to extract the required data from Spotify's API

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = config.client_ID, client_secret = config.client_secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %% [markdown]
# ### Importing the Data from the Dataset

# %%
def get_sliced_data(path, slices_limit = 10):
    # Get a list of all the files in the directory
    file_list = os.listdir(path)
    
    #Create an empty list with all JSON files
    data_list = []
    
    # Loop through the files and open each one
    for counter, filename in enumerate(file_list):
        # Construct the full file path
        file_path = os.path.join(path, filename)

        # Open the file and load the data into a variable
        with open(file_path, 'r') as f:
            data = json.load(f)
            data = pd.json_normalize(data)['playlists'][0]
            data_list.append(data)
        
        # Exit the Loop if the max number of slices (files) has been reached
        if counter == slices_limit:
            break

    # Return the whole Dataset as a list of JSONs
    return data_list

# %%
def make_data_df(data_list):
    # Create an empty list to store the flattened dictionaries
    flat_list = []

    # Flatten the dictionaries and add them to the list
    for sub_list in data_list:
        for sub_dict in sub_list:
            flat_list.append(sub_dict)
            
    # Convert the flattened list of dictionaries to a pandas DataFrame
    df = pd.DataFrame(flat_list)

    return df

# %%
path = r'C:\Users\yakin\Downloads\spotify_million_playlist_dataset\data'
data = get_sliced_data(path, slices_limit = 0)

# %%
df = make_data_df(data)
df
# Out:
#                  name collaborative  pid  modified_at  num_tracks  num_albums  \
# 0          Throwbacks         false    0   1493424000          52          47
# 1    Awesome Playlist         false    1   1506556800          39          23
# 2             korean          false    2   1505692800          64          51
# 3                 mat         false    3   1501027200         126         107
# 4                 90s         false    4   1401667200          17          16
# ..                ...           ...  ...          ...         ...         ...
# 995               old         false  995   1507852800          41          40
# 996              Daze         false  996   1479254400          17          17
# 997               rap         false  997   1410307200         119          98
# 998           Country         false  998   1507939200         108          75
# 999   thinking of you         false  999   1507766400          44          43
#
#      num_followers                                             tracks  \
# 0                1  [{'pos': 0, 'artist_name': 'Missy Elliott', 't...
# 1                1  [{'pos': 0, 'artist_name': 'Survivor', 'track_...
# 2                1  [{'pos': 0, 'artist_name': 'Hoody', 'track_uri...
# 3                1  [{'pos': 0, 'artist_name': 'Camille Saint-Saën...
# 4                2  [{'pos': 0, 'artist_name': 'The Smashing Pumpk...
# ..             ...                                                ...
# 995              1  [{'pos': 0, 'artist_name': 'Katrina', 'track_u...
# 996              1  [{'pos': 0, 'artist_name': 'PARTYNEXTDOOR', 't...
# 997              1  [{'pos': 0, 'artist_name': 'LoveRance', 'track...
# 998              1  [{'pos': 0, 'artist_name': 'Hunter Hayes', 'tr...
# 999              1  [{'pos': 0, 'artist_name': 'Pvris', 'track_uri...
#
#      num_edits  duration_ms  num_artists description
# 0            6     11532414           37         NaN
# 1            5     11656470           21         NaN
# 2           18     14039958           31         NaN
# 3            4     28926058           86         NaN
# 4            7      4335282           16         NaN
# ..         ...          ...          ...         ...
# 995          8      9917901           36         NaN
# 996         13      3699248           15         NaN
# 997         63     27538723           82         NaN
# 998         37     24950143           40         NaN
# 999         34      9065801           37         NaN
#
# [1000 rows x 12 columns]

# %% [markdown]
# ### Extracting the information from every track in every playlist

# %%
def extract_tracks_data(df):
    # Normalize the JSON data into a DataFrame for the entire 'tracks' column
    track_data = pd.json_normalize(df['tracks'].explode())

    # Drop unnecessary columns
    final_df = track_data.drop(['pos', 'duration_ms'], axis=1)

    # Set 'track_uri' as the index for efficient duplicate removal
    final_df.set_index('track_uri', inplace=True)

    # Drop any repeated rows based on the index (i.e., 'track_uri')
    final_df = final_df[~final_df.index.duplicated()].reset_index()

    return final_df

# %%
track_df = extract_tracks_data(df)
track_df
# Out:
#                                   track_uri        artist_name  \
# 0      spotify:track:0UaMYEvWZi0ZqiDOoHU3YI      Missy Elliott
# 1      spotify:track:6I9VzXrHxO9rA9A5euc8Ak     Britney Spears
# 2      spotify:track:0WqIKmW4BTrj3eJFmnCKMv            Beyoncé
# 3      spotify:track:1AWQoqb9bSvzTjaLralEkT  Justin Timberlake
# 4      spotify:track:1lzr43nnXAijIGYnCT8M8H             Shaggy
# ...                                     ...                ...
# 34438  spotify:track:3uCHI1gfOUL5j5swEh0TcH              Jon D
# 34439  spotify:track:0P1oO2gREMYUCoOkzYAyFu          Big Words
# 34440  spotify:track:2oM4BuruDnEvk59IvIXCwn       Allan Rayman
# 34441  spotify:track:4Ri5TTUgjM96tbQZd5Ua7V          Jon Jason
# 34442  spotify:track:5RVuBrXVLptAEbGJdSDzL5           Grizfolk
#
#                                   artist_uri  \
# 0      spotify:artist:2wIVse2owClT7go1WT98tk
# 1      spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 2      spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 3      spotify:artist:31TPClRtHm23RisEBtV3X7
# 4      spotify:artist:5EvFsr3kj42KNv97ZEnqij
# ...                                      ...
# 34438  spotify:artist:5HCypjplgh5uQezvBpOfXN
# 34439  spotify:artist:0sHN89qak07mnug3LVVjzP
# 34440  spotify:artist:6Yv6OBXD6ZQakEljaGaDAk
# 34441  spotify:artist:77bNdkKYBBmc30CisCA6tE
# 34442  spotify:artist:6Xa4nbrSTfbioA4lLShbjh
#
#                                          track_name  \
# 0        Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                             Toxic
# 2                                     Crazy In Love
# 3                                    Rock Your Body
# 4                                      It Wasn't Me
# ...                                             ...
# 34438                                  I Don't Know
# 34439                                    The Answer
# 34440                                         25.22
# 34441                                  Good Feeling
# 34442  Cosmic Angel - Acoustic From Capitol Studios
#
#                                   album_uri  \
# 0      spotify:album:6vV5UrXcfyQD1wu4Qo2I9K
# 1      spotify:album:0z7pVBGOD7HCIB7S8eLkLI
# 2      spotify:album:25hVFAxTlDvXbx2X2QkUkE
# 3      spotify:album:6QPkyl04rXwTGlGlcYaRoW
# 4      spotify:album:6NmFmPX56pcLBOFMhIiKvF
# ...                                     ...
# 34438  spotify:album:2KEQtuVl1cYsTYtVRUrNVi
# 34439  spotify:album:5jrsRHRAmetu5e7RRBoxj7
# 34440  spotify:album:3CbNgBzI7r9o0F6VjH9sTY
# 34441  spotify:album:2dZ7oVNQBeLlpoUYfbEsJP
# 34442  spotify:album:7D6Y19tjm4DQNch39FeWpO
#
#                                          album_name
# 0                                      The Cookbook
# 1                                       In The Zone
# 2      Dangerously In Love (Alben für die Ewigkeit)
# 3                                         Justified
# 4                                          Hot Shot
# ...                                             ...
# 34438                                         Roots
# 34439            Hollywood, a Beautiful Coincidence
# 34440                                  Roadhouse 01
# 34441                                  Good Feeling
# 34442                                  Cosmic Angel
#
# [34443 rows x 6 columns]

# %%
#additional_info_df = get_additional_info(track_df)
#additional_info_df

# %% [markdown]
# ### Requesting to Spotify's API the features of every Track in the dataset

# %%
def extract_track_features(df, batch_size = 50, verbose = True):
  # Set 'track_uri' as the index for efficient merging
  df = df.set_index('track_uri')
  
  # Get a list of all the track URIs in the DataFrame
  track_uris = df.index.to_list()
  
  # Calculate the number of batches needed based on batch size
  num_batches = math.ceil(len(track_uris) / batch_size)
  
  # Initialize an empty list to store the results
  audio_features = []
  
  # Make requests to the Spotify API in batches of size 'batch_size'
  for i in range(num_batches):
    # Calculate the start and end indices of the current batch
    start_idx = i * batch_size
    end_idx = min((i + 1) * batch_size, len(track_uris))
    
    # Extract the track URIs for the current batch
    track_batch_uris = track_uris[start_idx:end_idx]
    
    # Request audio features and track's data for the current batch of track URIs from the Spotify API
    track_batch_features = sp.audio_features(track_batch_uris)
    
    # Extend the list of audio features with the results of the current batch
    audio_features.extend(track_batch_features)
    
    #If Verbose is Enabled, the function will print current API requests status in terminal.
    if verbose:
      print(f'----------------------------------------------------------------------------------')
      print(f'Actual Batch: {i}. Number of Tracks retrieved: {i * batch_size}. Tracks Remaining: {len(df) - i * batch_size}')

  # Create a list of dictionaries with only the desired keys
  desired_keys = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature', 'uri']
  audio_features = [{k: track.get(k) for k in desired_keys} for track in audio_features]
  
  # Convert audio_features list to DataFrame
  features_df = pd.DataFrame(audio_features)
  
  # Merge audio features DataFrame with the final_df based on 'track_uri' index
  final_df = df.merge(features_df, left_index = True, right_on= 'uri')
  final_df = final_df.rename(columns = {'uri' : 'track_uri'})
  
  return final_df

# %%
track_features_df = extract_track_features(track_df)
track_features_df
# Out:
# ----------------------------------------------------------------------------------
# Actual Batch: 0. Number of Tracks retrieved: 0. Tracks Remaining: 34443
# ----------------------------------------------------------------------------------
# Actual Batch: 1. Number of Tracks retrieved: 50. Tracks Remaining: 34393
# ----------------------------------------------------------------------------------
# Actual Batch: 2. Number of Tracks retrieved: 100. Tracks Remaining: 34343
# ----------------------------------------------------------------------------------
# Actual Batch: 3. Number of Tracks retrieved: 150. Tracks Remaining: 34293
# ----------------------------------------------------------------------------------
# Actual Batch: 4. Number of Tracks retrieved: 200. Tracks Remaining: 34243
# ----------------------------------------------------------------------------------
# Actual Batch: 5. Number of Tracks retrieved: 250. Tracks Remaining: 34193
# ----------------------------------------------------------------------------------
# Actual Batch: 6. Number of Tracks retrieved: 300. Tracks Remaining: 34143
# ----------------------------------------------------------------------------------
# Actual Batch: 7. Number of Tracks retrieved: 350. Tracks Remaining: 34093
# ----------------------------------------------------------------------------------
# Actual Batch: 8. Number of Tracks retrieved: 400. Tracks Remaining: 34043
# ----------------------------------------------------------------------------------
# Actual Batch: 9. Number of Tracks retrieved: 450. Tracks Remaining: 33993
# ----------------------------------------------------------------------------------
# Actual Batch: 10. Number of Tracks retrieved: 500. Tracks Remaining: 33943
# ----------------------------------------------------------------------------------
# Actual Batch: 11. Number of Tracks retrieved: 550. Tracks Remaining: 33893
# ----------------------------------------------------------------------------------
# Actual Batch: 12. Number of Tracks retrieved: 600. Tracks Remaining: 33843
# ----------------------------------------------------------------------------------
# Actual Batch: 13. Number of Tracks retrieved: 650. Tracks Remaining: 33793
# ----------------------------------------------------------------------------------
# Actual Batch: 14. Number of Tracks retrieved: 700. Tracks Remaining: 33743
# ----------------------------------------------------------------------------------
# Actual Batch: 15. Number of Tracks retrieved: 750. Tracks Remaining: 33693
# ----------------------------------------------------------------------------------
# Actual Batch: 16. Number of Tracks retrieved: 800. Tracks Remaining: 33643
# ----------------------------------------------------------------------------------
# Actual Batch: 17. Number of Tracks retrieved: 850. Tracks Remaining: 33593
# ----------------------------------------------------------------------------------
# Actual Batch: 18. Number of Tracks retrieved: 900. Tracks Remaining: 33543
# ----------------------------------------------------------------------------------
# Actual Batch: 19. Number of Tracks retrieved: 950. Tracks Remaining: 33493
# ----------------------------------------------------------------------------------
# Actual Batch: 20. Number of Tracks retrieved: 1000. Tracks Remaining: 33443
# ----------------------------------------------------------------------------------
# Actual Batch: 21. Number of Tracks retrieved: 1050. Tracks Remaining: 33393
# ----------------------------------------------------------------------------------
# Actual Batch: 22. Number of Tracks retrieved: 1100. Tracks Remaining: 33343
# ----------------------------------------------------------------------------------
# Actual Batch: 23. Number of Tracks retrieved: 1150. Tracks Remaining: 33293
# ----------------------------------------------------------------------------------
# Actual Batch: 24. Number of Tracks retrieved: 1200. Tracks Remaining: 33243
# ----------------------------------------------------------------------------------
# Actual Batch: 25. Number of Tracks retrieved: 1250. Tracks Remaining: 33193
# ----------------------------------------------------------------------------------
# Actual Batch: 26. Number of Tracks retrieved: 1300. Tracks Remaining: 33143
# ----------------------------------------------------------------------------------
# Actual Batch: 27. Number of Tracks retrieved: 1350. Tracks Remaining: 33093
# ----------------------------------------------------------------------------------
# Actual Batch: 28. Number of Tracks retrieved: 1400. Tracks Remaining: 33043
# ----------------------------------------------------------------------------------
# Actual Batch: 29. Number of Tracks retrieved: 1450. Tracks Remaining: 32993
# ----------------------------------------------------------------------------------
# Actual Batch: 30. Number of Tracks retrieved: 1500. Tracks Remaining: 32943
# ----------------------------------------------------------------------------------
# Actual Batch: 31. Number of Tracks retrieved: 1550. Tracks Remaining: 32893
# ----------------------------------------------------------------------------------
# Actual Batch: 32. Number of Tracks retrieved: 1600. Tracks Remaining: 32843
# ----------------------------------------------------------------------------------
# Actual Batch: 33. Number of Tracks retrieved: 1650. Tracks Remaining: 32793
# ----------------------------------------------------------------------------------
# Actual Batch: 34. Number of Tracks retrieved: 1700. Tracks Remaining: 32743
# ----------------------------------------------------------------------------------
# Actual Batch: 35. Number of Tracks retrieved: 1750. Tracks Remaining: 32693
# ----------------------------------------------------------------------------------
# Actual Batch: 36. Number of Tracks retrieved: 1800. Tracks Remaining: 32643
# ----------------------------------------------------------------------------------
# Actual Batch: 37. Number of Tracks retrieved: 1850. Tracks Remaining: 32593
# ----------------------------------------------------------------------------------
# Actual Batch: 38. Number of Tracks retrieved: 1900. Tracks Remaining: 32543
# ----------------------------------------------------------------------------------
# Actual Batch: 39. Number of Tracks retrieved: 1950. Tracks Remaining: 32493
# ----------------------------------------------------------------------------------
# Actual Batch: 40. Number of Tracks retrieved: 2000. Tracks Remaining: 32443
# ----------------------------------------------------------------------------------
# Actual Batch: 41. Number of Tracks retrieved: 2050. Tracks Remaining: 32393
# ----------------------------------------------------------------------------------
# Actual Batch: 42. Number of Tracks retrieved: 2100. Tracks Remaining: 32343
# ----------------------------------------------------------------------------------
# Actual Batch: 43. Number of Tracks retrieved: 2150. Tracks Remaining: 32293
# ----------------------------------------------------------------------------------
# Actual Batch: 44. Number of Tracks retrieved: 2200. Tracks Remaining: 32243
# ----------------------------------------------------------------------------------
# Actual Batch: 45. Number of Tracks retrieved: 2250. Tracks Remaining: 32193
# ----------------------------------------------------------------------------------
# Actual Batch: 46. Number of Tracks retrieved: 2300. Tracks Remaining: 32143
# ----------------------------------------------------------------------------------
# Actual Batch: 47. Number of Tracks retrieved: 2350. Tracks Remaining: 32093
# ----------------------------------------------------------------------------------
# Actual Batch: 48. Number of Tracks retrieved: 2400. Tracks Remaining: 32043
# ----------------------------------------------------------------------------------
# Actual Batch: 49. Number of Tracks retrieved: 2450. Tracks Remaining: 31993
# ----------------------------------------------------------------------------------
# Actual Batch: 50. Number of Tracks retrieved: 2500. Tracks Remaining: 31943
# ----------------------------------------------------------------------------------
# Actual Batch: 51. Number of Tracks retrieved: 2550. Tracks Remaining: 31893
# ----------------------------------------------------------------------------------
# Actual Batch: 52. Number of Tracks retrieved: 2600. Tracks Remaining: 31843
# ----------------------------------------------------------------------------------
# Actual Batch: 53. Number of Tracks retrieved: 2650. Tracks Remaining: 31793
# ----------------------------------------------------------------------------------
# Actual Batch: 54. Number of Tracks retrieved: 2700. Tracks Remaining: 31743
# ----------------------------------------------------------------------------------
# Actual Batch: 55. Number of Tracks retrieved: 2750. Tracks Remaining: 31693
# ----------------------------------------------------------------------------------
# Actual Batch: 56. Number of Tracks retrieved: 2800. Tracks Remaining: 31643
# ----------------------------------------------------------------------------------
# Actual Batch: 57. Number of Tracks retrieved: 2850. Tracks Remaining: 31593
# ----------------------------------------------------------------------------------
# Actual Batch: 58. Number of Tracks retrieved: 2900. Tracks Remaining: 31543
# ----------------------------------------------------------------------------------
# Actual Batch: 59. Number of Tracks retrieved: 2950. Tracks Remaining: 31493
# ----------------------------------------------------------------------------------
# Actual Batch: 60. Number of Tracks retrieved: 3000. Tracks Remaining: 31443
# ----------------------------------------------------------------------------------
# Actual Batch: 61. Number of Tracks retrieved: 3050. Tracks Remaining: 31393
# ----------------------------------------------------------------------------------
# Actual Batch: 62. Number of Tracks retrieved: 3100. Tracks Remaining: 31343
# ----------------------------------------------------------------------------------
# Actual Batch: 63. Number of Tracks retrieved: 3150. Tracks Remaining: 31293
# ----------------------------------------------------------------------------------
# Actual Batch: 64. Number of Tracks retrieved: 3200. Tracks Remaining: 31243
# ----------------------------------------------------------------------------------
# Actual Batch: 65. Number of Tracks retrieved: 3250. Tracks Remaining: 31193
# ----------------------------------------------------------------------------------
# Actual Batch: 66. Number of Tracks retrieved: 3300. Tracks Remaining: 31143
# ----------------------------------------------------------------------------------
# Actual Batch: 67. Number of Tracks retrieved: 3350. Tracks Remaining: 31093
# ----------------------------------------------------------------------------------
# Actual Batch: 68. Number of Tracks retrieved: 3400. Tracks Remaining: 31043
# ----------------------------------------------------------------------------------
# Actual Batch: 69. Number of Tracks retrieved: 3450. Tracks Remaining: 30993
# ----------------------------------------------------------------------------------
# Actual Batch: 70. Number of Tracks retrieved: 3500. Tracks Remaining: 30943
# ----------------------------------------------------------------------------------
# Actual Batch: 71. Number of Tracks retrieved: 3550. Tracks Remaining: 30893
# ----------------------------------------------------------------------------------
# Actual Batch: 72. Number of Tracks retrieved: 3600. Tracks Remaining: 30843
# ----------------------------------------------------------------------------------
# Actual Batch: 73. Number of Tracks retrieved: 3650. Tracks Remaining: 30793
# ----------------------------------------------------------------------------------
# Actual Batch: 74. Number of Tracks retrieved: 3700. Tracks Remaining: 30743
# ----------------------------------------------------------------------------------
# Actual Batch: 75. Number of Tracks retrieved: 3750. Tracks Remaining: 30693
# ----------------------------------------------------------------------------------
# Actual Batch: 76. Number of Tracks retrieved: 3800. Tracks Remaining: 30643
# ----------------------------------------------------------------------------------
# Actual Batch: 77. Number of Tracks retrieved: 3850. Tracks Remaining: 30593
# ----------------------------------------------------------------------------------
# Actual Batch: 78. Number of Tracks retrieved: 3900. Tracks Remaining: 30543
# ----------------------------------------------------------------------------------
# Actual Batch: 79. Number of Tracks retrieved: 3950. Tracks Remaining: 30493
# ----------------------------------------------------------------------------------
# Actual Batch: 80. Number of Tracks retrieved: 4000. Tracks Remaining: 30443
# ----------------------------------------------------------------------------------
# Actual Batch: 81. Number of Tracks retrieved: 4050. Tracks Remaining: 30393
# ----------------------------------------------------------------------------------
# Actual Batch: 82. Number of Tracks retrieved: 4100. Tracks Remaining: 30343
# ----------------------------------------------------------------------------------
# Actual Batch: 83. Number of Tracks retrieved: 4150. Tracks Remaining: 30293
# ----------------------------------------------------------------------------------
# Actual Batch: 84. Number of Tracks retrieved: 4200. Tracks Remaining: 30243
# ----------------------------------------------------------------------------------
# Actual Batch: 85. Number of Tracks retrieved: 4250. Tracks Remaining: 30193
# ----------------------------------------------------------------------------------
# Actual Batch: 86. Number of Tracks retrieved: 4300. Tracks Remaining: 30143
# ----------------------------------------------------------------------------------
# Actual Batch: 87. Number of Tracks retrieved: 4350. Tracks Remaining: 30093
# ----------------------------------------------------------------------------------
# Actual Batch: 88. Number of Tracks retrieved: 4400. Tracks Remaining: 30043
# ----------------------------------------------------------------------------------
# Actual Batch: 89. Number of Tracks retrieved: 4450. Tracks Remaining: 29993
# ----------------------------------------------------------------------------------
# Actual Batch: 90. Number of Tracks retrieved: 4500. Tracks Remaining: 29943
# ----------------------------------------------------------------------------------
# Actual Batch: 91. Number of Tracks retrieved: 4550. Tracks Remaining: 29893
# ----------------------------------------------------------------------------------
# Actual Batch: 92. Number of Tracks retrieved: 4600. Tracks Remaining: 29843
# ----------------------------------------------------------------------------------
# Actual Batch: 93. Number of Tracks retrieved: 4650. Tracks Remaining: 29793
# ----------------------------------------------------------------------------------
# Actual Batch: 94. Number of Tracks retrieved: 4700. Tracks Remaining: 29743
# ----------------------------------------------------------------------------------
# Actual Batch: 95. Number of Tracks retrieved: 4750. Tracks Remaining: 29693
# ----------------------------------------------------------------------------------
# Actual Batch: 96. Number of Tracks retrieved: 4800. Tracks Remaining: 29643
# ----------------------------------------------------------------------------------
# Actual Batch: 97. Number of Tracks retrieved: 4850. Tracks Remaining: 29593
# ----------------------------------------------------------------------------------
# Actual Batch: 98. Number of Tracks retrieved: 4900. Tracks Remaining: 29543
# ----------------------------------------------------------------------------------
# Actual Batch: 99. Number of Tracks retrieved: 4950. Tracks Remaining: 29493
# ----------------------------------------------------------------------------------
# Actual Batch: 100. Number of Tracks retrieved: 5000. Tracks Remaining: 29443
# ----------------------------------------------------------------------------------
# Actual Batch: 101. Number of Tracks retrieved: 5050. Tracks Remaining: 29393
# ----------------------------------------------------------------------------------
# Actual Batch: 102. Number of Tracks retrieved: 5100. Tracks Remaining: 29343
# ----------------------------------------------------------------------------------
# Actual Batch: 103. Number of Tracks retrieved: 5150. Tracks Remaining: 29293
# ----------------------------------------------------------------------------------
# Actual Batch: 104. Number of Tracks retrieved: 5200. Tracks Remaining: 29243
# ----------------------------------------------------------------------------------
# Actual Batch: 105. Number of Tracks retrieved: 5250. Tracks Remaining: 29193
# ----------------------------------------------------------------------------------
# Actual Batch: 106. Number of Tracks retrieved: 5300. Tracks Remaining: 29143
# ----------------------------------------------------------------------------------
# Actual Batch: 107. Number of Tracks retrieved: 5350. Tracks Remaining: 29093
# ----------------------------------------------------------------------------------
# Actual Batch: 108. Number of Tracks retrieved: 5400. Tracks Remaining: 29043
# ----------------------------------------------------------------------------------
# Actual Batch: 109. Number of Tracks retrieved: 5450. Tracks Remaining: 28993
# ----------------------------------------------------------------------------------
# Actual Batch: 110. Number of Tracks retrieved: 5500. Tracks Remaining: 28943
# ----------------------------------------------------------------------------------
# Actual Batch: 111. Number of Tracks retrieved: 5550. Tracks Remaining: 28893
# ----------------------------------------------------------------------------------
# Actual Batch: 112. Number of Tracks retrieved: 5600. Tracks Remaining: 28843
# ----------------------------------------------------------------------------------
# Actual Batch: 113. Number of Tracks retrieved: 5650. Tracks Remaining: 28793
# ----------------------------------------------------------------------------------
# Actual Batch: 114. Number of Tracks retrieved: 5700. Tracks Remaining: 28743
# ----------------------------------------------------------------------------------
# Actual Batch: 115. Number of Tracks retrieved: 5750. Tracks Remaining: 28693
# ----------------------------------------------------------------------------------
# Actual Batch: 116. Number of Tracks retrieved: 5800. Tracks Remaining: 28643
# ----------------------------------------------------------------------------------
# Actual Batch: 117. Number of Tracks retrieved: 5850. Tracks Remaining: 28593
# ----------------------------------------------------------------------------------
# Actual Batch: 118. Number of Tracks retrieved: 5900. Tracks Remaining: 28543
# ----------------------------------------------------------------------------------
# Actual Batch: 119. Number of Tracks retrieved: 5950. Tracks Remaining: 28493
# ----------------------------------------------------------------------------------
# Actual Batch: 120. Number of Tracks retrieved: 6000. Tracks Remaining: 28443
# ----------------------------------------------------------------------------------
# Actual Batch: 121. Number of Tracks retrieved: 6050. Tracks Remaining: 28393
# ----------------------------------------------------------------------------------
# Actual Batch: 122. Number of Tracks retrieved: 6100. Tracks Remaining: 28343
# ----------------------------------------------------------------------------------
# Actual Batch: 123. Number of Tracks retrieved: 6150. Tracks Remaining: 28293
# ----------------------------------------------------------------------------------
# Actual Batch: 124. Number of Tracks retrieved: 6200. Tracks Remaining: 28243
# ----------------------------------------------------------------------------------
# Actual Batch: 125. Number of Tracks retrieved: 6250. Tracks Remaining: 28193
# ----------------------------------------------------------------------------------
# Actual Batch: 126. Number of Tracks retrieved: 6300. Tracks Remaining: 28143
# ----------------------------------------------------------------------------------
# Actual Batch: 127. Number of Tracks retrieved: 6350. Tracks Remaining: 28093
# ----------------------------------------------------------------------------------
# Actual Batch: 128. Number of Tracks retrieved: 6400. Tracks Remaining: 28043
# ----------------------------------------------------------------------------------
# Actual Batch: 129. Number of Tracks retrieved: 6450. Tracks Remaining: 27993
# ----------------------------------------------------------------------------------
# Actual Batch: 130. Number of Tracks retrieved: 6500. Tracks Remaining: 27943
# ----------------------------------------------------------------------------------
# Actual Batch: 131. Number of Tracks retrieved: 6550. Tracks Remaining: 27893
# ----------------------------------------------------------------------------------
# Actual Batch: 132. Number of Tracks retrieved: 6600. Tracks Remaining: 27843
# ----------------------------------------------------------------------------------
# Actual Batch: 133. Number of Tracks retrieved: 6650. Tracks Remaining: 27793
# ----------------------------------------------------------------------------------
# Actual Batch: 134. Number of Tracks retrieved: 6700. Tracks Remaining: 27743
# ----------------------------------------------------------------------------------
# Actual Batch: 135. Number of Tracks retrieved: 6750. Tracks Remaining: 27693
# ----------------------------------------------------------------------------------
# Actual Batch: 136. Number of Tracks retrieved: 6800. Tracks Remaining: 27643
# ----------------------------------------------------------------------------------
# Actual Batch: 137. Number of Tracks retrieved: 6850. Tracks Remaining: 27593
# ----------------------------------------------------------------------------------
# Actual Batch: 138. Number of Tracks retrieved: 6900. Tracks Remaining: 27543
# ----------------------------------------------------------------------------------
# Actual Batch: 139. Number of Tracks retrieved: 6950. Tracks Remaining: 27493
# ----------------------------------------------------------------------------------
# Actual Batch: 140. Number of Tracks retrieved: 7000. Tracks Remaining: 27443
# ----------------------------------------------------------------------------------
# Actual Batch: 141. Number of Tracks retrieved: 7050. Tracks Remaining: 27393
# ----------------------------------------------------------------------------------
# Actual Batch: 142. Number of Tracks retrieved: 7100. Tracks Remaining: 27343
# ----------------------------------------------------------------------------------
# Actual Batch: 143. Number of Tracks retrieved: 7150. Tracks Remaining: 27293
# ----------------------------------------------------------------------------------
# Actual Batch: 144. Number of Tracks retrieved: 7200. Tracks Remaining: 27243
# ----------------------------------------------------------------------------------
# Actual Batch: 145. Number of Tracks retrieved: 7250. Tracks Remaining: 27193
# ----------------------------------------------------------------------------------
# Actual Batch: 146. Number of Tracks retrieved: 7300. Tracks Remaining: 27143
# ----------------------------------------------------------------------------------
# Actual Batch: 147. Number of Tracks retrieved: 7350. Tracks Remaining: 27093
# ----------------------------------------------------------------------------------
# Actual Batch: 148. Number of Tracks retrieved: 7400. Tracks Remaining: 27043
# ----------------------------------------------------------------------------------
# Actual Batch: 149. Number of Tracks retrieved: 7450. Tracks Remaining: 26993
# ----------------------------------------------------------------------------------
# Actual Batch: 150. Number of Tracks retrieved: 7500. Tracks Remaining: 26943
# ----------------------------------------------------------------------------------
# Actual Batch: 151. Number of Tracks retrieved: 7550. Tracks Remaining: 26893
# ----------------------------------------------------------------------------------
# Actual Batch: 152. Number of Tracks retrieved: 7600. Tracks Remaining: 26843
# ----------------------------------------------------------------------------------
# Actual Batch: 153. Number of Tracks retrieved: 7650. Tracks Remaining: 26793
# ----------------------------------------------------------------------------------
# Actual Batch: 154. Number of Tracks retrieved: 7700. Tracks Remaining: 26743
# ----------------------------------------------------------------------------------
# Actual Batch: 155. Number of Tracks retrieved: 7750. Tracks Remaining: 26693
# ----------------------------------------------------------------------------------
# Actual Batch: 156. Number of Tracks retrieved: 7800. Tracks Remaining: 26643
# ----------------------------------------------------------------------------------
# Actual Batch: 157. Number of Tracks retrieved: 7850. Tracks Remaining: 26593
# ----------------------------------------------------------------------------------
# Actual Batch: 158. Number of Tracks retrieved: 7900. Tracks Remaining: 26543
# ----------------------------------------------------------------------------------
# Actual Batch: 159. Number of Tracks retrieved: 7950. Tracks Remaining: 26493
# ----------------------------------------------------------------------------------
# Actual Batch: 160. Number of Tracks retrieved: 8000. Tracks Remaining: 26443
# ----------------------------------------------------------------------------------
# Actual Batch: 161. Number of Tracks retrieved: 8050. Tracks Remaining: 26393
# ----------------------------------------------------------------------------------
# Actual Batch: 162. Number of Tracks retrieved: 8100. Tracks Remaining: 26343
# ----------------------------------------------------------------------------------
# Actual Batch: 163. Number of Tracks retrieved: 8150. Tracks Remaining: 26293
# ----------------------------------------------------------------------------------
# Actual Batch: 164. Number of Tracks retrieved: 8200. Tracks Remaining: 26243
# ----------------------------------------------------------------------------------
# Actual Batch: 165. Number of Tracks retrieved: 8250. Tracks Remaining: 26193
# ----------------------------------------------------------------------------------
# Actual Batch: 166. Number of Tracks retrieved: 8300. Tracks Remaining: 26143
# ----------------------------------------------------------------------------------
# Actual Batch: 167. Number of Tracks retrieved: 8350. Tracks Remaining: 26093
# ----------------------------------------------------------------------------------
# Actual Batch: 168. Number of Tracks retrieved: 8400. Tracks Remaining: 26043
# ----------------------------------------------------------------------------------
# Actual Batch: 169. Number of Tracks retrieved: 8450. Tracks Remaining: 25993
# ----------------------------------------------------------------------------------
# Actual Batch: 170. Number of Tracks retrieved: 8500. Tracks Remaining: 25943
# ----------------------------------------------------------------------------------
# Actual Batch: 171. Number of Tracks retrieved: 8550. Tracks Remaining: 25893
# ----------------------------------------------------------------------------------
# Actual Batch: 172. Number of Tracks retrieved: 8600. Tracks Remaining: 25843
# ----------------------------------------------------------------------------------
# Actual Batch: 173. Number of Tracks retrieved: 8650. Tracks Remaining: 25793
# ----------------------------------------------------------------------------------
# Actual Batch: 174. Number of Tracks retrieved: 8700. Tracks Remaining: 25743
# ----------------------------------------------------------------------------------
# Actual Batch: 175. Number of Tracks retrieved: 8750. Tracks Remaining: 25693
# ----------------------------------------------------------------------------------
# Actual Batch: 176. Number of Tracks retrieved: 8800. Tracks Remaining: 25643
# ----------------------------------------------------------------------------------
# Actual Batch: 177. Number of Tracks retrieved: 8850. Tracks Remaining: 25593
# ----------------------------------------------------------------------------------
# Actual Batch: 178. Number of Tracks retrieved: 8900. Tracks Remaining: 25543
# ----------------------------------------------------------------------------------
# Actual Batch: 179. Number of Tracks retrieved: 8950. Tracks Remaining: 25493
# ----------------------------------------------------------------------------------
# Actual Batch: 180. Number of Tracks retrieved: 9000. Tracks Remaining: 25443
# ----------------------------------------------------------------------------------
# Actual Batch: 181. Number of Tracks retrieved: 9050. Tracks Remaining: 25393
# ----------------------------------------------------------------------------------
# Actual Batch: 182. Number of Tracks retrieved: 9100. Tracks Remaining: 25343
# ----------------------------------------------------------------------------------
# Actual Batch: 183. Number of Tracks retrieved: 9150. Tracks Remaining: 25293
# ----------------------------------------------------------------------------------
# Actual Batch: 184. Number of Tracks retrieved: 9200. Tracks Remaining: 25243
# ----------------------------------------------------------------------------------
# Actual Batch: 185. Number of Tracks retrieved: 9250. Tracks Remaining: 25193
# ----------------------------------------------------------------------------------
# Actual Batch: 186. Number of Tracks retrieved: 9300. Tracks Remaining: 25143
# ----------------------------------------------------------------------------------
# Actual Batch: 187. Number of Tracks retrieved: 9350. Tracks Remaining: 25093
# ----------------------------------------------------------------------------------
# Actual Batch: 188. Number of Tracks retrieved: 9400. Tracks Remaining: 25043
# ----------------------------------------------------------------------------------
# Actual Batch: 189. Number of Tracks retrieved: 9450. Tracks Remaining: 24993
# ----------------------------------------------------------------------------------
# Actual Batch: 190. Number of Tracks retrieved: 9500. Tracks Remaining: 24943
# ----------------------------------------------------------------------------------
# Actual Batch: 191. Number of Tracks retrieved: 9550. Tracks Remaining: 24893
# ----------------------------------------------------------------------------------
# Actual Batch: 192. Number of Tracks retrieved: 9600. Tracks Remaining: 24843
# ----------------------------------------------------------------------------------
# Actual Batch: 193. Number of Tracks retrieved: 9650. Tracks Remaining: 24793
# ----------------------------------------------------------------------------------
# Actual Batch: 194. Number of Tracks retrieved: 9700. Tracks Remaining: 24743
# ----------------------------------------------------------------------------------
# Actual Batch: 195. Number of Tracks retrieved: 9750. Tracks Remaining: 24693
# ----------------------------------------------------------------------------------
# Actual Batch: 196. Number of Tracks retrieved: 9800. Tracks Remaining: 24643
# ----------------------------------------------------------------------------------
# Actual Batch: 197. Number of Tracks retrieved: 9850. Tracks Remaining: 24593
# ----------------------------------------------------------------------------------
# Actual Batch: 198. Number of Tracks retrieved: 9900. Tracks Remaining: 24543
# ----------------------------------------------------------------------------------
# Actual Batch: 199. Number of Tracks retrieved: 9950. Tracks Remaining: 24493
# ----------------------------------------------------------------------------------
# Actual Batch: 200. Number of Tracks retrieved: 10000. Tracks Remaining: 24443
# ----------------------------------------------------------------------------------
# Actual Batch: 201. Number of Tracks retrieved: 10050. Tracks Remaining: 24393
# ----------------------------------------------------------------------------------
# Actual Batch: 202. Number of Tracks retrieved: 10100. Tracks Remaining: 24343
# ----------------------------------------------------------------------------------
# Actual Batch: 203. Number of Tracks retrieved: 10150. Tracks Remaining: 24293
# ----------------------------------------------------------------------------------
# Actual Batch: 204. Number of Tracks retrieved: 10200. Tracks Remaining: 24243
# ----------------------------------------------------------------------------------
# Actual Batch: 205. Number of Tracks retrieved: 10250. Tracks Remaining: 24193
# ----------------------------------------------------------------------------------
# Actual Batch: 206. Number of Tracks retrieved: 10300. Tracks Remaining: 24143
# ----------------------------------------------------------------------------------
# Actual Batch: 207. Number of Tracks retrieved: 10350. Tracks Remaining: 24093
# ----------------------------------------------------------------------------------
# Actual Batch: 208. Number of Tracks retrieved: 10400. Tracks Remaining: 24043
# ----------------------------------------------------------------------------------
# Actual Batch: 209. Number of Tracks retrieved: 10450. Tracks Remaining: 23993
# ----------------------------------------------------------------------------------
# Actual Batch: 210. Number of Tracks retrieved: 10500. Tracks Remaining: 23943
# ----------------------------------------------------------------------------------
# Actual Batch: 211. Number of Tracks retrieved: 10550. Tracks Remaining: 23893
# ----------------------------------------------------------------------------------
# Actual Batch: 212. Number of Tracks retrieved: 10600. Tracks Remaining: 23843
# ----------------------------------------------------------------------------------
# Actual Batch: 213. Number of Tracks retrieved: 10650. Tracks Remaining: 23793
# ----------------------------------------------------------------------------------
# Actual Batch: 214. Number of Tracks retrieved: 10700. Tracks Remaining: 23743
# ----------------------------------------------------------------------------------
# Actual Batch: 215. Number of Tracks retrieved: 10750. Tracks Remaining: 23693
# ----------------------------------------------------------------------------------
# Actual Batch: 216. Number of Tracks retrieved: 10800. Tracks Remaining: 23643
# ----------------------------------------------------------------------------------
# Actual Batch: 217. Number of Tracks retrieved: 10850. Tracks Remaining: 23593
# ----------------------------------------------------------------------------------
# Actual Batch: 218. Number of Tracks retrieved: 10900. Tracks Remaining: 23543
# ----------------------------------------------------------------------------------
# Actual Batch: 219. Number of Tracks retrieved: 10950. Tracks Remaining: 23493
# ----------------------------------------------------------------------------------
# Actual Batch: 220. Number of Tracks retrieved: 11000. Tracks Remaining: 23443
# ----------------------------------------------------------------------------------
# Actual Batch: 221. Number of Tracks retrieved: 11050. Tracks Remaining: 23393
# ----------------------------------------------------------------------------------
# Actual Batch: 222. Number of Tracks retrieved: 11100. Tracks Remaining: 23343
# ----------------------------------------------------------------------------------
# Actual Batch: 223. Number of Tracks retrieved: 11150. Tracks Remaining: 23293
# ----------------------------------------------------------------------------------
# Actual Batch: 224. Number of Tracks retrieved: 11200. Tracks Remaining: 23243
# ----------------------------------------------------------------------------------
# Actual Batch: 225. Number of Tracks retrieved: 11250. Tracks Remaining: 23193
# ----------------------------------------------------------------------------------
# Actual Batch: 226. Number of Tracks retrieved: 11300. Tracks Remaining: 23143
# ----------------------------------------------------------------------------------
# Actual Batch: 227. Number of Tracks retrieved: 11350. Tracks Remaining: 23093
# ----------------------------------------------------------------------------------
# Actual Batch: 228. Number of Tracks retrieved: 11400. Tracks Remaining: 23043
# ----------------------------------------------------------------------------------
# Actual Batch: 229. Number of Tracks retrieved: 11450. Tracks Remaining: 22993
# ----------------------------------------------------------------------------------
# Actual Batch: 230. Number of Tracks retrieved: 11500. Tracks Remaining: 22943
# ----------------------------------------------------------------------------------
# Actual Batch: 231. Number of Tracks retrieved: 11550. Tracks Remaining: 22893
# ----------------------------------------------------------------------------------
# Actual Batch: 232. Number of Tracks retrieved: 11600. Tracks Remaining: 22843
# ----------------------------------------------------------------------------------
# Actual Batch: 233. Number of Tracks retrieved: 11650. Tracks Remaining: 22793
# ----------------------------------------------------------------------------------
# Actual Batch: 234. Number of Tracks retrieved: 11700. Tracks Remaining: 22743
# ----------------------------------------------------------------------------------
# Actual Batch: 235. Number of Tracks retrieved: 11750. Tracks Remaining: 22693
# ----------------------------------------------------------------------------------
# Actual Batch: 236. Number of Tracks retrieved: 11800. Tracks Remaining: 22643
# ----------------------------------------------------------------------------------
# Actual Batch: 237. Number of Tracks retrieved: 11850. Tracks Remaining: 22593
# ----------------------------------------------------------------------------------
# Actual Batch: 238. Number of Tracks retrieved: 11900. Tracks Remaining: 22543
# ----------------------------------------------------------------------------------
# Actual Batch: 239. Number of Tracks retrieved: 11950. Tracks Remaining: 22493
# ----------------------------------------------------------------------------------
# Actual Batch: 240. Number of Tracks retrieved: 12000. Tracks Remaining: 22443
# ----------------------------------------------------------------------------------
# Actual Batch: 241. Number of Tracks retrieved: 12050. Tracks Remaining: 22393
# ----------------------------------------------------------------------------------
# Actual Batch: 242. Number of Tracks retrieved: 12100. Tracks Remaining: 22343
# ----------------------------------------------------------------------------------
# Actual Batch: 243. Number of Tracks retrieved: 12150. Tracks Remaining: 22293
# ----------------------------------------------------------------------------------
# Actual Batch: 244. Number of Tracks retrieved: 12200. Tracks Remaining: 22243
# ----------------------------------------------------------------------------------
# Actual Batch: 245. Number of Tracks retrieved: 12250. Tracks Remaining: 22193
# ----------------------------------------------------------------------------------
# Actual Batch: 246. Number of Tracks retrieved: 12300. Tracks Remaining: 22143
# ----------------------------------------------------------------------------------
# Actual Batch: 247. Number of Tracks retrieved: 12350. Tracks Remaining: 22093
# ----------------------------------------------------------------------------------
# Actual Batch: 248. Number of Tracks retrieved: 12400. Tracks Remaining: 22043
# ----------------------------------------------------------------------------------
# Actual Batch: 249. Number of Tracks retrieved: 12450. Tracks Remaining: 21993
# ----------------------------------------------------------------------------------
# Actual Batch: 250. Number of Tracks retrieved: 12500. Tracks Remaining: 21943
# ----------------------------------------------------------------------------------
# Actual Batch: 251. Number of Tracks retrieved: 12550. Tracks Remaining: 21893
# ----------------------------------------------------------------------------------
# Actual Batch: 252. Number of Tracks retrieved: 12600. Tracks Remaining: 21843
# ----------------------------------------------------------------------------------
# Actual Batch: 253. Number of Tracks retrieved: 12650. Tracks Remaining: 21793
# ----------------------------------------------------------------------------------
# Actual Batch: 254. Number of Tracks retrieved: 12700. Tracks Remaining: 21743
# ----------------------------------------------------------------------------------
# Actual Batch: 255. Number of Tracks retrieved: 12750. Tracks Remaining: 21693
# ----------------------------------------------------------------------------------
# Actual Batch: 256. Number of Tracks retrieved: 12800. Tracks Remaining: 21643
# ----------------------------------------------------------------------------------
# Actual Batch: 257. Number of Tracks retrieved: 12850. Tracks Remaining: 21593
# ----------------------------------------------------------------------------------
# Actual Batch: 258. Number of Tracks retrieved: 12900. Tracks Remaining: 21543
# ----------------------------------------------------------------------------------
# Actual Batch: 259. Number of Tracks retrieved: 12950. Tracks Remaining: 21493
# ----------------------------------------------------------------------------------
# Actual Batch: 260. Number of Tracks retrieved: 13000. Tracks Remaining: 21443
# ----------------------------------------------------------------------------------
# Actual Batch: 261. Number of Tracks retrieved: 13050. Tracks Remaining: 21393
# ----------------------------------------------------------------------------------
# Actual Batch: 262. Number of Tracks retrieved: 13100. Tracks Remaining: 21343
# ----------------------------------------------------------------------------------
# Actual Batch: 263. Number of Tracks retrieved: 13150. Tracks Remaining: 21293
# ----------------------------------------------------------------------------------
# Actual Batch: 264. Number of Tracks retrieved: 13200. Tracks Remaining: 21243
# ----------------------------------------------------------------------------------
# Actual Batch: 265. Number of Tracks retrieved: 13250. Tracks Remaining: 21193
# ----------------------------------------------------------------------------------
# Actual Batch: 266. Number of Tracks retrieved: 13300. Tracks Remaining: 21143
# ----------------------------------------------------------------------------------
# Actual Batch: 267. Number of Tracks retrieved: 13350. Tracks Remaining: 21093
# ----------------------------------------------------------------------------------
# Actual Batch: 268. Number of Tracks retrieved: 13400. Tracks Remaining: 21043
# ----------------------------------------------------------------------------------
# Actual Batch: 269. Number of Tracks retrieved: 13450. Tracks Remaining: 20993
# ----------------------------------------------------------------------------------
# Actual Batch: 270. Number of Tracks retrieved: 13500. Tracks Remaining: 20943
# ----------------------------------------------------------------------------------
# Actual Batch: 271. Number of Tracks retrieved: 13550. Tracks Remaining: 20893
# ----------------------------------------------------------------------------------
# Actual Batch: 272. Number of Tracks retrieved: 13600. Tracks Remaining: 20843
# ----------------------------------------------------------------------------------
# Actual Batch: 273. Number of Tracks retrieved: 13650. Tracks Remaining: 20793
# ----------------------------------------------------------------------------------
# Actual Batch: 274. Number of Tracks retrieved: 13700. Tracks Remaining: 20743
# ----------------------------------------------------------------------------------
# Actual Batch: 275. Number of Tracks retrieved: 13750. Tracks Remaining: 20693
# ----------------------------------------------------------------------------------
# Actual Batch: 276. Number of Tracks retrieved: 13800. Tracks Remaining: 20643
# ----------------------------------------------------------------------------------
# Actual Batch: 277. Number of Tracks retrieved: 13850. Tracks Remaining: 20593
# ----------------------------------------------------------------------------------
# Actual Batch: 278. Number of Tracks retrieved: 13900. Tracks Remaining: 20543
# ----------------------------------------------------------------------------------
# Actual Batch: 279. Number of Tracks retrieved: 13950. Tracks Remaining: 20493
# ----------------------------------------------------------------------------------
# Actual Batch: 280. Number of Tracks retrieved: 14000. Tracks Remaining: 20443
# ----------------------------------------------------------------------------------
# Actual Batch: 281. Number of Tracks retrieved: 14050. Tracks Remaining: 20393
# ----------------------------------------------------------------------------------
# Actual Batch: 282. Number of Tracks retrieved: 14100. Tracks Remaining: 20343
# ----------------------------------------------------------------------------------
# Actual Batch: 283. Number of Tracks retrieved: 14150. Tracks Remaining: 20293
# ----------------------------------------------------------------------------------
# Actual Batch: 284. Number of Tracks retrieved: 14200. Tracks Remaining: 20243
# ----------------------------------------------------------------------------------
# Actual Batch: 285. Number of Tracks retrieved: 14250. Tracks Remaining: 20193
# ----------------------------------------------------------------------------------
# Actual Batch: 286. Number of Tracks retrieved: 14300. Tracks Remaining: 20143
# ----------------------------------------------------------------------------------
# Actual Batch: 287. Number of Tracks retrieved: 14350. Tracks Remaining: 20093
# ----------------------------------------------------------------------------------
# Actual Batch: 288. Number of Tracks retrieved: 14400. Tracks Remaining: 20043
# ----------------------------------------------------------------------------------
# Actual Batch: 289. Number of Tracks retrieved: 14450. Tracks Remaining: 19993
# ----------------------------------------------------------------------------------
# Actual Batch: 290. Number of Tracks retrieved: 14500. Tracks Remaining: 19943
# ----------------------------------------------------------------------------------
# Actual Batch: 291. Number of Tracks retrieved: 14550. Tracks Remaining: 19893
# ----------------------------------------------------------------------------------
# Actual Batch: 292. Number of Tracks retrieved: 14600. Tracks Remaining: 19843
# ----------------------------------------------------------------------------------
# Actual Batch: 293. Number of Tracks retrieved: 14650. Tracks Remaining: 19793
# ----------------------------------------------------------------------------------
# Actual Batch: 294. Number of Tracks retrieved: 14700. Tracks Remaining: 19743
# ----------------------------------------------------------------------------------
# Actual Batch: 295. Number of Tracks retrieved: 14750. Tracks Remaining: 19693
# ----------------------------------------------------------------------------------
# Actual Batch: 296. Number of Tracks retrieved: 14800. Tracks Remaining: 19643
# ----------------------------------------------------------------------------------
# Actual Batch: 297. Number of Tracks retrieved: 14850. Tracks Remaining: 19593
# ----------------------------------------------------------------------------------
# Actual Batch: 298. Number of Tracks retrieved: 14900. Tracks Remaining: 19543
# ----------------------------------------------------------------------------------
# Actual Batch: 299. Number of Tracks retrieved: 14950. Tracks Remaining: 19493
# ...
# ----------------------------------------------------------------------------------
# Actual Batch: 622. Number of Tracks retrieved: 31100. Tracks Remaining: 3343
# ----------------------------------------------------------------------------------
# Actual Batch: 623. Number of Tracks retrieved: 31150. Tracks Remaining: 3293
# ----------------------------------------------------------------------------------
# Actual Batch: 624. Number of Tracks retrieved: 31200. Tracks Remaining: 3243
# ----------------------------------------------------------------------------------
# Actual Batch: 625. Number of Tracks retrieved: 31250. Tracks Remaining: 3193
# ----------------------------------------------------------------------------------
# Actual Batch: 626. Number of Tracks retrieved: 31300. Tracks Remaining: 3143
# ----------------------------------------------------------------------------------
# Actual Batch: 627. Number of Tracks retrieved: 31350. Tracks Remaining: 3093
# ----------------------------------------------------------------------------------
# Actual Batch: 628. Number of Tracks retrieved: 31400. Tracks Remaining: 3043
# ----------------------------------------------------------------------------------
# Actual Batch: 629. Number of Tracks retrieved: 31450. Tracks Remaining: 2993
# ----------------------------------------------------------------------------------
# Actual Batch: 630. Number of Tracks retrieved: 31500. Tracks Remaining: 2943
# ----------------------------------------------------------------------------------
# Actual Batch: 631. Number of Tracks retrieved: 31550. Tracks Remaining: 2893
# ----------------------------------------------------------------------------------
# Actual Batch: 632. Number of Tracks retrieved: 31600. Tracks Remaining: 2843
# ----------------------------------------------------------------------------------
# Actual Batch: 633. Number of Tracks retrieved: 31650. Tracks Remaining: 2793
# ----------------------------------------------------------------------------------
# Actual Batch: 634. Number of Tracks retrieved: 31700. Tracks Remaining: 2743
# ----------------------------------------------------------------------------------
# Actual Batch: 635. Number of Tracks retrieved: 31750. Tracks Remaining: 2693
# ----------------------------------------------------------------------------------
# Actual Batch: 636. Number of Tracks retrieved: 31800. Tracks Remaining: 2643
# ----------------------------------------------------------------------------------
# Actual Batch: 637. Number of Tracks retrieved: 31850. Tracks Remaining: 2593
# ----------------------------------------------------------------------------------
# Actual Batch: 638. Number of Tracks retrieved: 31900. Tracks Remaining: 2543
# ----------------------------------------------------------------------------------
# Actual Batch: 639. Number of Tracks retrieved: 31950. Tracks Remaining: 2493
# ----------------------------------------------------------------------------------
# Actual Batch: 640. Number of Tracks retrieved: 32000. Tracks Remaining: 2443
# ----------------------------------------------------------------------------------
# Actual Batch: 641. Number of Tracks retrieved: 32050. Tracks Remaining: 2393
# ----------------------------------------------------------------------------------
# Actual Batch: 642. Number of Tracks retrieved: 32100. Tracks Remaining: 2343
# ----------------------------------------------------------------------------------
# Actual Batch: 643. Number of Tracks retrieved: 32150. Tracks Remaining: 2293
# ----------------------------------------------------------------------------------
# Actual Batch: 644. Number of Tracks retrieved: 32200. Tracks Remaining: 2243
# ----------------------------------------------------------------------------------
# Actual Batch: 645. Number of Tracks retrieved: 32250. Tracks Remaining: 2193
# ----------------------------------------------------------------------------------
# Actual Batch: 646. Number of Tracks retrieved: 32300. Tracks Remaining: 2143
# ----------------------------------------------------------------------------------
# Actual Batch: 647. Number of Tracks retrieved: 32350. Tracks Remaining: 2093
# ----------------------------------------------------------------------------------
# Actual Batch: 648. Number of Tracks retrieved: 32400. Tracks Remaining: 2043
# ----------------------------------------------------------------------------------
# Actual Batch: 649. Number of Tracks retrieved: 32450. Tracks Remaining: 1993
# ----------------------------------------------------------------------------------
# Actual Batch: 650. Number of Tracks retrieved: 32500. Tracks Remaining: 1943
# ----------------------------------------------------------------------------------
# Actual Batch: 651. Number of Tracks retrieved: 32550. Tracks Remaining: 1893
# ----------------------------------------------------------------------------------
# Actual Batch: 652. Number of Tracks retrieved: 32600. Tracks Remaining: 1843
# ----------------------------------------------------------------------------------
# Actual Batch: 653. Number of Tracks retrieved: 32650. Tracks Remaining: 1793
# ----------------------------------------------------------------------------------
# Actual Batch: 654. Number of Tracks retrieved: 32700. Tracks Remaining: 1743
# ----------------------------------------------------------------------------------
# Actual Batch: 655. Number of Tracks retrieved: 32750. Tracks Remaining: 1693
# ----------------------------------------------------------------------------------
# Actual Batch: 656. Number of Tracks retrieved: 32800. Tracks Remaining: 1643
# ----------------------------------------------------------------------------------
# Actual Batch: 657. Number of Tracks retrieved: 32850. Tracks Remaining: 1593
# ----------------------------------------------------------------------------------
# Actual Batch: 658. Number of Tracks retrieved: 32900. Tracks Remaining: 1543
# ----------------------------------------------------------------------------------
# Actual Batch: 659. Number of Tracks retrieved: 32950. Tracks Remaining: 1493
# ----------------------------------------------------------------------------------
# Actual Batch: 660. Number of Tracks retrieved: 33000. Tracks Remaining: 1443
# ----------------------------------------------------------------------------------
# Actual Batch: 661. Number of Tracks retrieved: 33050. Tracks Remaining: 1393
# ----------------------------------------------------------------------------------
# Actual Batch: 662. Number of Tracks retrieved: 33100. Tracks Remaining: 1343
# ----------------------------------------------------------------------------------
# Actual Batch: 663. Number of Tracks retrieved: 33150. Tracks Remaining: 1293
# ----------------------------------------------------------------------------------
# Actual Batch: 664. Number of Tracks retrieved: 33200. Tracks Remaining: 1243
# ----------------------------------------------------------------------------------
# Actual Batch: 665. Number of Tracks retrieved: 33250. Tracks Remaining: 1193
# ----------------------------------------------------------------------------------
# Actual Batch: 666. Number of Tracks retrieved: 33300. Tracks Remaining: 1143
# ----------------------------------------------------------------------------------
# Actual Batch: 667. Number of Tracks retrieved: 33350. Tracks Remaining: 1093
# ----------------------------------------------------------------------------------
# Actual Batch: 668. Number of Tracks retrieved: 33400. Tracks Remaining: 1043
# ----------------------------------------------------------------------------------
# Actual Batch: 669. Number of Tracks retrieved: 33450. Tracks Remaining: 993
# ----------------------------------------------------------------------------------
# Actual Batch: 670. Number of Tracks retrieved: 33500. Tracks Remaining: 943
# ----------------------------------------------------------------------------------
# Actual Batch: 671. Number of Tracks retrieved: 33550. Tracks Remaining: 893
# ----------------------------------------------------------------------------------
# Actual Batch: 672. Number of Tracks retrieved: 33600. Tracks Remaining: 843
# ----------------------------------------------------------------------------------
# Actual Batch: 673. Number of Tracks retrieved: 33650. Tracks Remaining: 793
# ----------------------------------------------------------------------------------
# Actual Batch: 674. Number of Tracks retrieved: 33700. Tracks Remaining: 743
# ----------------------------------------------------------------------------------
# Actual Batch: 675. Number of Tracks retrieved: 33750. Tracks Remaining: 693
# ----------------------------------------------------------------------------------
# Actual Batch: 676. Number of Tracks retrieved: 33800. Tracks Remaining: 643
# ----------------------------------------------------------------------------------
# Actual Batch: 677. Number of Tracks retrieved: 33850. Tracks Remaining: 593
# ----------------------------------------------------------------------------------
# Actual Batch: 678. Number of Tracks retrieved: 33900. Tracks Remaining: 543
# ----------------------------------------------------------------------------------
# Actual Batch: 679. Number of Tracks retrieved: 33950. Tracks Remaining: 493
# ----------------------------------------------------------------------------------
# Actual Batch: 680. Number of Tracks retrieved: 34000. Tracks Remaining: 443
# ----------------------------------------------------------------------------------
# Actual Batch: 681. Number of Tracks retrieved: 34050. Tracks Remaining: 393
# ----------------------------------------------------------------------------------
# Actual Batch: 682. Number of Tracks retrieved: 34100. Tracks Remaining: 343
# ----------------------------------------------------------------------------------
# Actual Batch: 683. Number of Tracks retrieved: 34150. Tracks Remaining: 293
# ----------------------------------------------------------------------------------
# Actual Batch: 684. Number of Tracks retrieved: 34200. Tracks Remaining: 243
# ----------------------------------------------------------------------------------
# Actual Batch: 685. Number of Tracks retrieved: 34250. Tracks Remaining: 193
# ----------------------------------------------------------------------------------
# Actual Batch: 686. Number of Tracks retrieved: 34300. Tracks Remaining: 143
# ----------------------------------------------------------------------------------
# Actual Batch: 687. Number of Tracks retrieved: 34350. Tracks Remaining: 93
# ----------------------------------------------------------------------------------
# Actual Batch: 688. Number of Tracks retrieved: 34400. Tracks Remaining: 43
#              artist_name                             artist_uri  \
# 0          Missy Elliott  spotify:artist:2wIVse2owClT7go1WT98tk
# 1         Britney Spears  spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 2                Beyoncé  spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 3      Justin Timberlake  spotify:artist:31TPClRtHm23RisEBtV3X7
# 4                 Shaggy  spotify:artist:5EvFsr3kj42KNv97ZEnqij
# ...                  ...                                    ...
# 34438              Jon D  spotify:artist:5HCypjplgh5uQezvBpOfXN
# 34439          Big Words  spotify:artist:0sHN89qak07mnug3LVVjzP
# 34440       Allan Rayman  spotify:artist:6Yv6OBXD6ZQakEljaGaDAk
# 34441          Jon Jason  spotify:artist:77bNdkKYBBmc30CisCA6tE
# 34442           Grizfolk  spotify:artist:6Xa4nbrSTfbioA4lLShbjh
#
#                                          track_name  \
# 0        Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                             Toxic
# 2                                     Crazy In Love
# 3                                    Rock Your Body
# 4                                      It Wasn't Me
# ...                                             ...
# 34438                                  I Don't Know
# 34439                                    The Answer
# 34440                                         25.22
# 34441                                  Good Feeling
# 34442  Cosmic Angel - Acoustic From Capitol Studios
#
#                                   album_uri  \
# 0      spotify:album:6vV5UrXcfyQD1wu4Qo2I9K
# 1      spotify:album:0z7pVBGOD7HCIB7S8eLkLI
# 2      spotify:album:25hVFAxTlDvXbx2X2QkUkE
# 3      spotify:album:6QPkyl04rXwTGlGlcYaRoW
# 4      spotify:album:6NmFmPX56pcLBOFMhIiKvF
# ...                                     ...
# 34438  spotify:album:2KEQtuVl1cYsTYtVRUrNVi
# 34439  spotify:album:5jrsRHRAmetu5e7RRBoxj7
# 34440  spotify:album:3CbNgBzI7r9o0F6VjH9sTY
# 34441  spotify:album:2dZ7oVNQBeLlpoUYfbEsJP
# 34442  spotify:album:7D6Y19tjm4DQNch39FeWpO
#
#                                          album_name  danceability  energy  \
# 0                                      The Cookbook         0.904   0.813
# 1                                       In The Zone         0.774   0.838
# 2      Dangerously In Love (Alben für die Ewigkeit)         0.664   0.758
# 3                                         Justified         0.892   0.714
# 4                                          Hot Shot         0.853   0.606
# ...                                             ...           ...     ...
# 34438                                         Roots         0.669   0.228
# 34439            Hollywood, a Beautiful Coincidence         0.493   0.727
# 34440                                  Roadhouse 01         0.702   0.524
# 34441                                  Good Feeling         0.509   0.286
# 34442                                  Cosmic Angel         0.639   0.461
#
#        key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0        4    -7.105     0       0.1210       0.03110          0.006970
# 1        5    -3.914     0       0.1140       0.02490          0.025000
# 2        2    -6.583     0       0.2100       0.00238          0.000000
# 3        4    -6.055     0       0.1410       0.20100          0.000234
# 4        0    -4.596     1       0.0713       0.05610          0.000000
# ...    ...       ...   ...          ...           ...               ...
# 34438    2   -12.119     1       0.0690       0.79200          0.065000
# 34439    1    -5.031     1       0.2170       0.08730          0.000000
# 34440    7   -10.710     1       0.0793       0.33200          0.055300
# 34441    8   -14.722     1       0.1230       0.40200          0.000012
# 34442    6    -8.260     0       0.0493       0.35700          0.000057
#
#        liveness  valence    tempo  duration_ms  time_signature  \
# 0        0.0471    0.810  125.461       226864               4
# 1        0.2420    0.924  143.040       198800               4
# 2        0.0598    0.701   99.259       235933               4
# 3        0.0521    0.817  100.972       267267               4
# 4        0.3130    0.654   94.759       227600               4
# ...         ...      ...      ...          ...             ...
# 34438    0.0944    0.402   83.024       189184               4
# 34439    0.1290    0.289   73.259       263680               4
# 34440    0.2980    0.265  140.089       189213               4
# 34441    0.1310    0.259  121.633       194720               4
# 34442    0.1120    0.264  117.583       257195               4
#
#                                   track_uri
# 0      spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1      spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2      spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3      spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4      spotify:track:1lzr43nnXAijIGYnCT8M8H
# ...                                     ...
# 34438  spotify:track:3uCHI1gfOUL5j5swEh0TcH
# 34439  spotify:track:0P1oO2gREMYUCoOkzYAyFu
# 34440  spotify:track:2oM4BuruDnEvk59IvIXCwn
# 34441  spotify:track:4Ri5TTUgjM96tbQZd5Ua7V
# 34442  spotify:track:5RVuBrXVLptAEbGJdSDzL5
#
# [34443 rows x 19 columns]

# %% [markdown]
# ### Requesting to Spotify's API the features of every Artist in the dataset

# %%
def extract_artist_features(df, batch_size = 50, verbose = True):
    
    # Set 'artist_uri' as the index for efficient merging
    df = df.set_index('artist_uri')

    #Get all the Artist's URIs from dataframe
    artist_uris = df.index.to_list()

    # Calculate the number of batches needed based on batch size
    num_batches = math.ceil(len(artist_uris) / batch_size)

    # Initialize an empty list to store the results
    artists_features = []
    
    # Make requests to the Spotify API in batches of size 'batch_size'
    for i in range(num_batches):
        print(f'Started Gathering Data')
        # Calculate the start and end indices of the current batch
        start_idx = i * batch_size
        end_idx = min((i + 1) * batch_size, len(artist_uris))
        
        # Extract the artists URIs for the current batch
        artist_batch_uris = artist_uris[start_idx:end_idx]
        
        print(f'Making API Request...')
        # Request audio features for the current batch of artist URIs from the Spotify API
        artist_batch_features = sp.artists(artist_batch_uris)
        print(f'Succesful!')
        
        # Extend the list of artists features with the results of the current batch
        artists_features.extend(artist_batch_features['artists'])
        
        #If Verbose is Enabled, the function will print current API requests status in terminal.
        if verbose:
            print(f'----------------------------------------------------------------------------------')
            print(f'Actual Batch: {i}. Number of Tracks retrieved: {i * batch_size}. Tracks Remaining: {len(df) - i * batch_size}')
            
    # Convert audio_features list to DataFrame
    features_df = pd.DataFrame(artists_features)
    
    # Remove duplicates based on the 'uri' column
    features_df = features_df.drop_duplicates(subset='uri')
    
    #Drop unnecesary columns
    drop_columns = ['external_urls', 'followers', 'href', 'id', 'images', 'name', 'type']
    features_df = features_df.drop(drop_columns, axis = 1)
    
    # Merge audio features DataFrame with the final_df based on 'artist_uri' index
    final_df = df.merge(features_df, left_index = True, right_on= 'uri')
    final_df = final_df.rename(columns = {'uri' : 'artist_uri', 'popularity': 'artist_popularity'})
    
    return final_df

# %%
artist_df = extract_artist_features(track_features_df)
artist_df
# Out:
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 0. Number of Tracks retrieved: 0. Tracks Remaining: 34443
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 1. Number of Tracks retrieved: 50. Tracks Remaining: 34393
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 2. Number of Tracks retrieved: 100. Tracks Remaining: 34343
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 3. Number of Tracks retrieved: 150. Tracks Remaining: 34293
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 4. Number of Tracks retrieved: 200. Tracks Remaining: 34243
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 5. Number of Tracks retrieved: 250. Tracks Remaining: 34193
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 6. Number of Tracks retrieved: 300. Tracks Remaining: 34143
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 7. Number of Tracks retrieved: 350. Tracks Remaining: 34093
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 8. Number of Tracks retrieved: 400. Tracks Remaining: 34043
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 9. Number of Tracks retrieved: 450. Tracks Remaining: 33993
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 10. Number of Tracks retrieved: 500. Tracks Remaining: 33943
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 11. Number of Tracks retrieved: 550. Tracks Remaining: 33893
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 12. Number of Tracks retrieved: 600. Tracks Remaining: 33843
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 13. Number of Tracks retrieved: 650. Tracks Remaining: 33793
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 14. Number of Tracks retrieved: 700. Tracks Remaining: 33743
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 15. Number of Tracks retrieved: 750. Tracks Remaining: 33693
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 16. Number of Tracks retrieved: 800. Tracks Remaining: 33643
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 17. Number of Tracks retrieved: 850. Tracks Remaining: 33593
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 18. Number of Tracks retrieved: 900. Tracks Remaining: 33543
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 19. Number of Tracks retrieved: 950. Tracks Remaining: 33493
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 20. Number of Tracks retrieved: 1000. Tracks Remaining: 33443
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 21. Number of Tracks retrieved: 1050. Tracks Remaining: 33393
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 22. Number of Tracks retrieved: 1100. Tracks Remaining: 33343
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 23. Number of Tracks retrieved: 1150. Tracks Remaining: 33293
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 24. Number of Tracks retrieved: 1200. Tracks Remaining: 33243
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 25. Number of Tracks retrieved: 1250. Tracks Remaining: 33193
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 26. Number of Tracks retrieved: 1300. Tracks Remaining: 33143
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 27. Number of Tracks retrieved: 1350. Tracks Remaining: 33093
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 28. Number of Tracks retrieved: 1400. Tracks Remaining: 33043
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 29. Number of Tracks retrieved: 1450. Tracks Remaining: 32993
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 30. Number of Tracks retrieved: 1500. Tracks Remaining: 32943
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 31. Number of Tracks retrieved: 1550. Tracks Remaining: 32893
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 32. Number of Tracks retrieved: 1600. Tracks Remaining: 32843
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 33. Number of Tracks retrieved: 1650. Tracks Remaining: 32793
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 34. Number of Tracks retrieved: 1700. Tracks Remaining: 32743
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 35. Number of Tracks retrieved: 1750. Tracks Remaining: 32693
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 36. Number of Tracks retrieved: 1800. Tracks Remaining: 32643
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 37. Number of Tracks retrieved: 1850. Tracks Remaining: 32593
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 38. Number of Tracks retrieved: 1900. Tracks Remaining: 32543
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 39. Number of Tracks retrieved: 1950. Tracks Remaining: 32493
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 40. Number of Tracks retrieved: 2000. Tracks Remaining: 32443
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 41. Number of Tracks retrieved: 2050. Tracks Remaining: 32393
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 42. Number of Tracks retrieved: 2100. Tracks Remaining: 32343
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 43. Number of Tracks retrieved: 2150. Tracks Remaining: 32293
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 44. Number of Tracks retrieved: 2200. Tracks Remaining: 32243
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 45. Number of Tracks retrieved: 2250. Tracks Remaining: 32193
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 46. Number of Tracks retrieved: 2300. Tracks Remaining: 32143
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 47. Number of Tracks retrieved: 2350. Tracks Remaining: 32093
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 48. Number of Tracks retrieved: 2400. Tracks Remaining: 32043
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 49. Number of Tracks retrieved: 2450. Tracks Remaining: 31993
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 50. Number of Tracks retrieved: 2500. Tracks Remaining: 31943
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 51. Number of Tracks retrieved: 2550. Tracks Remaining: 31893
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 52. Number of Tracks retrieved: 2600. Tracks Remaining: 31843
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 53. Number of Tracks retrieved: 2650. Tracks Remaining: 31793
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 54. Number of Tracks retrieved: 2700. Tracks Remaining: 31743
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 55. Number of Tracks retrieved: 2750. Tracks Remaining: 31693
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 56. Number of Tracks retrieved: 2800. Tracks Remaining: 31643
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 57. Number of Tracks retrieved: 2850. Tracks Remaining: 31593
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 58. Number of Tracks retrieved: 2900. Tracks Remaining: 31543
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 59. Number of Tracks retrieved: 2950. Tracks Remaining: 31493
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 60. Number of Tracks retrieved: 3000. Tracks Remaining: 31443
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 61. Number of Tracks retrieved: 3050. Tracks Remaining: 31393
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 62. Number of Tracks retrieved: 3100. Tracks Remaining: 31343
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 63. Number of Tracks retrieved: 3150. Tracks Remaining: 31293
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 64. Number of Tracks retrieved: 3200. Tracks Remaining: 31243
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 65. Number of Tracks retrieved: 3250. Tracks Remaining: 31193
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 66. Number of Tracks retrieved: 3300. Tracks Remaining: 31143
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 67. Number of Tracks retrieved: 3350. Tracks Remaining: 31093
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 68. Number of Tracks retrieved: 3400. Tracks Remaining: 31043
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 69. Number of Tracks retrieved: 3450. Tracks Remaining: 30993
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 70. Number of Tracks retrieved: 3500. Tracks Remaining: 30943
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 71. Number of Tracks retrieved: 3550. Tracks Remaining: 30893
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 72. Number of Tracks retrieved: 3600. Tracks Remaining: 30843
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 73. Number of Tracks retrieved: 3650. Tracks Remaining: 30793
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 74. Number of Tracks retrieved: 3700. Tracks Remaining: 30743
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 75. Number of Tracks retrieved: 3750. Tracks Remaining: 30693
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 76. Number of Tracks retrieved: 3800. Tracks Remaining: 30643
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 77. Number of Tracks retrieved: 3850. Tracks Remaining: 30593
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 78. Number of Tracks retrieved: 3900. Tracks Remaining: 30543
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 79. Number of Tracks retrieved: 3950. Tracks Remaining: 30493
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 80. Number of Tracks retrieved: 4000. Tracks Remaining: 30443
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 81. Number of Tracks retrieved: 4050. Tracks Remaining: 30393
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 82. Number of Tracks retrieved: 4100. Tracks Remaining: 30343
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 83. Number of Tracks retrieved: 4150. Tracks Remaining: 30293
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 84. Number of Tracks retrieved: 4200. Tracks Remaining: 30243
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 85. Number of Tracks retrieved: 4250. Tracks Remaining: 30193
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 86. Number of Tracks retrieved: 4300. Tracks Remaining: 30143
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 87. Number of Tracks retrieved: 4350. Tracks Remaining: 30093
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 88. Number of Tracks retrieved: 4400. Tracks Remaining: 30043
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 89. Number of Tracks retrieved: 4450. Tracks Remaining: 29993
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 90. Number of Tracks retrieved: 4500. Tracks Remaining: 29943
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 91. Number of Tracks retrieved: 4550. Tracks Remaining: 29893
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 92. Number of Tracks retrieved: 4600. Tracks Remaining: 29843
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 93. Number of Tracks retrieved: 4650. Tracks Remaining: 29793
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 94. Number of Tracks retrieved: 4700. Tracks Remaining: 29743
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 95. Number of Tracks retrieved: 4750. Tracks Remaining: 29693
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 96. Number of Tracks retrieved: 4800. Tracks Remaining: 29643
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 97. Number of Tracks retrieved: 4850. Tracks Remaining: 29593
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 98. Number of Tracks retrieved: 4900. Tracks Remaining: 29543
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 99. Number of Tracks retrieved: 4950. Tracks Remaining: 29493
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 100. Number of Tracks retrieved: 5000. Tracks Remaining: 29443
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 101. Number of Tracks retrieved: 5050. Tracks Remaining: 29393
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 102. Number of Tracks retrieved: 5100. Tracks Remaining: 29343
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 103. Number of Tracks retrieved: 5150. Tracks Remaining: 29293
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 104. Number of Tracks retrieved: 5200. Tracks Remaining: 29243
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 105. Number of Tracks retrieved: 5250. Tracks Remaining: 29193
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 106. Number of Tracks retrieved: 5300. Tracks Remaining: 29143
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 107. Number of Tracks retrieved: 5350. Tracks Remaining: 29093
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 108. Number of Tracks retrieved: 5400. Tracks Remaining: 29043
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 109. Number of Tracks retrieved: 5450. Tracks Remaining: 28993
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 110. Number of Tracks retrieved: 5500. Tracks Remaining: 28943
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 111. Number of Tracks retrieved: 5550. Tracks Remaining: 28893
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 112. Number of Tracks retrieved: 5600. Tracks Remaining: 28843
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 113. Number of Tracks retrieved: 5650. Tracks Remaining: 28793
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 114. Number of Tracks retrieved: 5700. Tracks Remaining: 28743
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 115. Number of Tracks retrieved: 5750. Tracks Remaining: 28693
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 116. Number of Tracks retrieved: 5800. Tracks Remaining: 28643
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 117. Number of Tracks retrieved: 5850. Tracks Remaining: 28593
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 118. Number of Tracks retrieved: 5900. Tracks Remaining: 28543
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 119. Number of Tracks retrieved: 5950. Tracks Remaining: 28493
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 120. Number of Tracks retrieved: 6000. Tracks Remaining: 28443
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 121. Number of Tracks retrieved: 6050. Tracks Remaining: 28393
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 122. Number of Tracks retrieved: 6100. Tracks Remaining: 28343
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 123. Number of Tracks retrieved: 6150. Tracks Remaining: 28293
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 124. Number of Tracks retrieved: 6200. Tracks Remaining: 28243
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 125. Number of Tracks retrieved: 6250. Tracks Remaining: 28193
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 126. Number of Tracks retrieved: 6300. Tracks Remaining: 28143
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 127. Number of Tracks retrieved: 6350. Tracks Remaining: 28093
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 128. Number of Tracks retrieved: 6400. Tracks Remaining: 28043
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 129. Number of Tracks retrieved: 6450. Tracks Remaining: 27993
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 130. Number of Tracks retrieved: 6500. Tracks Remaining: 27943
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 131. Number of Tracks retrieved: 6550. Tracks Remaining: 27893
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 132. Number of Tracks retrieved: 6600. Tracks Remaining: 27843
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 133. Number of Tracks retrieved: 6650. Tracks Remaining: 27793
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 134. Number of Tracks retrieved: 6700. Tracks Remaining: 27743
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 135. Number of Tracks retrieved: 6750. Tracks Remaining: 27693
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 136. Number of Tracks retrieved: 6800. Tracks Remaining: 27643
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 137. Number of Tracks retrieved: 6850. Tracks Remaining: 27593
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 138. Number of Tracks retrieved: 6900. Tracks Remaining: 27543
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 139. Number of Tracks retrieved: 6950. Tracks Remaining: 27493
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 140. Number of Tracks retrieved: 7000. Tracks Remaining: 27443
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 141. Number of Tracks retrieved: 7050. Tracks Remaining: 27393
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 142. Number of Tracks retrieved: 7100. Tracks Remaining: 27343
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 143. Number of Tracks retrieved: 7150. Tracks Remaining: 27293
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 144. Number of Tracks retrieved: 7200. Tracks Remaining: 27243
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 145. Number of Tracks retrieved: 7250. Tracks Remaining: 27193
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 146. Number of Tracks retrieved: 7300. Tracks Remaining: 27143
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 147. Number of Tracks retrieved: 7350. Tracks Remaining: 27093
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 148. Number of Tracks retrieved: 7400. Tracks Remaining: 27043
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 149. Number of Tracks retrieved: 7450. Tracks Remaining: 26993
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 150. Number of Tracks retrieved: 7500. Tracks Remaining: 26943
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 151. Number of Tracks retrieved: 7550. Tracks Remaining: 26893
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 152. Number of Tracks retrieved: 7600. Tracks Remaining: 26843
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 153. Number of Tracks retrieved: 7650. Tracks Remaining: 26793
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 154. Number of Tracks retrieved: 7700. Tracks Remaining: 26743
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 155. Number of Tracks retrieved: 7750. Tracks Remaining: 26693
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 156. Number of Tracks retrieved: 7800. Tracks Remaining: 26643
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 157. Number of Tracks retrieved: 7850. Tracks Remaining: 26593
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 158. Number of Tracks retrieved: 7900. Tracks Remaining: 26543
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 159. Number of Tracks retrieved: 7950. Tracks Remaining: 26493
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 160. Number of Tracks retrieved: 8000. Tracks Remaining: 26443
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 161. Number of Tracks retrieved: 8050. Tracks Remaining: 26393
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 162. Number of Tracks retrieved: 8100. Tracks Remaining: 26343
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 163. Number of Tracks retrieved: 8150. Tracks Remaining: 26293
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 164. Number of Tracks retrieved: 8200. Tracks Remaining: 26243
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 165. Number of Tracks retrieved: 8250. Tracks Remaining: 26193
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 166. Number of Tracks retrieved: 8300. Tracks Remaining: 26143
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 167. Number of Tracks retrieved: 8350. Tracks Remaining: 26093
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 168. Number of Tracks retrieved: 8400. Tracks Remaining: 26043
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 169. Number of Tracks retrieved: 8450. Tracks Remaining: 25993
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 170. Number of Tracks retrieved: 8500. Tracks Remaining: 25943
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 171. Number of Tracks retrieved: 8550. Tracks Remaining: 25893
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 172. Number of Tracks retrieved: 8600. Tracks Remaining: 25843
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 173. Number of Tracks retrieved: 8650. Tracks Remaining: 25793
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 174. Number of Tracks retrieved: 8700. Tracks Remaining: 25743
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 175. Number of Tracks retrieved: 8750. Tracks Remaining: 25693
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 176. Number of Tracks retrieved: 8800. Tracks Remaining: 25643
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 177. Number of Tracks retrieved: 8850. Tracks Remaining: 25593
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 178. Number of Tracks retrieved: 8900. Tracks Remaining: 25543
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 179. Number of Tracks retrieved: 8950. Tracks Remaining: 25493
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 180. Number of Tracks retrieved: 9000. Tracks Remaining: 25443
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 181. Number of Tracks retrieved: 9050. Tracks Remaining: 25393
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 182. Number of Tracks retrieved: 9100. Tracks Remaining: 25343
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 183. Number of Tracks retrieved: 9150. Tracks Remaining: 25293
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 184. Number of Tracks retrieved: 9200. Tracks Remaining: 25243
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 185. Number of Tracks retrieved: 9250. Tracks Remaining: 25193
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 186. Number of Tracks retrieved: 9300. Tracks Remaining: 25143
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 187. Number of Tracks retrieved: 9350. Tracks Remaining: 25093
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 188. Number of Tracks retrieved: 9400. Tracks Remaining: 25043
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 189. Number of Tracks retrieved: 9450. Tracks Remaining: 24993
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 190. Number of Tracks retrieved: 9500. Tracks Remaining: 24943
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 191. Number of Tracks retrieved: 9550. Tracks Remaining: 24893
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 192. Number of Tracks retrieved: 9600. Tracks Remaining: 24843
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 193. Number of Tracks retrieved: 9650. Tracks Remaining: 24793
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 194. Number of Tracks retrieved: 9700. Tracks Remaining: 24743
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 195. Number of Tracks retrieved: 9750. Tracks Remaining: 24693
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 196. Number of Tracks retrieved: 9800. Tracks Remaining: 24643
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 197. Number of Tracks retrieved: 9850. Tracks Remaining: 24593
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 198. Number of Tracks retrieved: 9900. Tracks Remaining: 24543
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 199. Number of Tracks retrieved: 9950. Tracks Remaining: 24493
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 200. Number of Tracks retrieved: 10000. Tracks Remaining: 24443
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 201. Number of Tracks retrieved: 10050. Tracks Remaining: 24393
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 202. Number of Tracks retrieved: 10100. Tracks Remaining: 24343
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 203. Number of Tracks retrieved: 10150. Tracks Remaining: 24293
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 204. Number of Tracks retrieved: 10200. Tracks Remaining: 24243
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 205. Number of Tracks retrieved: 10250. Tracks Remaining: 24193
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 206. Number of Tracks retrieved: 10300. Tracks Remaining: 24143
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 207. Number of Tracks retrieved: 10350. Tracks Remaining: 24093
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 208. Number of Tracks retrieved: 10400. Tracks Remaining: 24043
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 209. Number of Tracks retrieved: 10450. Tracks Remaining: 23993
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 210. Number of Tracks retrieved: 10500. Tracks Remaining: 23943
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 211. Number of Tracks retrieved: 10550. Tracks Remaining: 23893
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 212. Number of Tracks retrieved: 10600. Tracks Remaining: 23843
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 213. Number of Tracks retrieved: 10650. Tracks Remaining: 23793
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 214. Number of Tracks retrieved: 10700. Tracks Remaining: 23743
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 215. Number of Tracks retrieved: 10750. Tracks Remaining: 23693
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 216. Number of Tracks retrieved: 10800. Tracks Remaining: 23643
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 217. Number of Tracks retrieved: 10850. Tracks Remaining: 23593
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 218. Number of Tracks retrieved: 10900. Tracks Remaining: 23543
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 219. Number of Tracks retrieved: 10950. Tracks Remaining: 23493
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 220. Number of Tracks retrieved: 11000. Tracks Remaining: 23443
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 221. Number of Tracks retrieved: 11050. Tracks Remaining: 23393
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# ...
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 642. Number of Tracks retrieved: 32100. Tracks Remaining: 2343
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 643. Number of Tracks retrieved: 32150. Tracks Remaining: 2293
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 644. Number of Tracks retrieved: 32200. Tracks Remaining: 2243
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 645. Number of Tracks retrieved: 32250. Tracks Remaining: 2193
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 646. Number of Tracks retrieved: 32300. Tracks Remaining: 2143
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 647. Number of Tracks retrieved: 32350. Tracks Remaining: 2093
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 648. Number of Tracks retrieved: 32400. Tracks Remaining: 2043
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 649. Number of Tracks retrieved: 32450. Tracks Remaining: 1993
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 650. Number of Tracks retrieved: 32500. Tracks Remaining: 1943
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 651. Number of Tracks retrieved: 32550. Tracks Remaining: 1893
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 652. Number of Tracks retrieved: 32600. Tracks Remaining: 1843
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 653. Number of Tracks retrieved: 32650. Tracks Remaining: 1793
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 654. Number of Tracks retrieved: 32700. Tracks Remaining: 1743
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 655. Number of Tracks retrieved: 32750. Tracks Remaining: 1693
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 656. Number of Tracks retrieved: 32800. Tracks Remaining: 1643
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 657. Number of Tracks retrieved: 32850. Tracks Remaining: 1593
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 658. Number of Tracks retrieved: 32900. Tracks Remaining: 1543
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 659. Number of Tracks retrieved: 32950. Tracks Remaining: 1493
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 660. Number of Tracks retrieved: 33000. Tracks Remaining: 1443
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 661. Number of Tracks retrieved: 33050. Tracks Remaining: 1393
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 662. Number of Tracks retrieved: 33100. Tracks Remaining: 1343
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 663. Number of Tracks retrieved: 33150. Tracks Remaining: 1293
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 664. Number of Tracks retrieved: 33200. Tracks Remaining: 1243
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 665. Number of Tracks retrieved: 33250. Tracks Remaining: 1193
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 666. Number of Tracks retrieved: 33300. Tracks Remaining: 1143
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 667. Number of Tracks retrieved: 33350. Tracks Remaining: 1093
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 668. Number of Tracks retrieved: 33400. Tracks Remaining: 1043
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 669. Number of Tracks retrieved: 33450. Tracks Remaining: 993
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 670. Number of Tracks retrieved: 33500. Tracks Remaining: 943
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 671. Number of Tracks retrieved: 33550. Tracks Remaining: 893
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 672. Number of Tracks retrieved: 33600. Tracks Remaining: 843
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 673. Number of Tracks retrieved: 33650. Tracks Remaining: 793
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 674. Number of Tracks retrieved: 33700. Tracks Remaining: 743
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 675. Number of Tracks retrieved: 33750. Tracks Remaining: 693
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 676. Number of Tracks retrieved: 33800. Tracks Remaining: 643
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 677. Number of Tracks retrieved: 33850. Tracks Remaining: 593
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 678. Number of Tracks retrieved: 33900. Tracks Remaining: 543
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 679. Number of Tracks retrieved: 33950. Tracks Remaining: 493
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 680. Number of Tracks retrieved: 34000. Tracks Remaining: 443
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 681. Number of Tracks retrieved: 34050. Tracks Remaining: 393
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 682. Number of Tracks retrieved: 34100. Tracks Remaining: 343
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 683. Number of Tracks retrieved: 34150. Tracks Remaining: 293
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 684. Number of Tracks retrieved: 34200. Tracks Remaining: 243
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 685. Number of Tracks retrieved: 34250. Tracks Remaining: 193
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 686. Number of Tracks retrieved: 34300. Tracks Remaining: 143
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 687. Number of Tracks retrieved: 34350. Tracks Remaining: 93
# Started Gathering Data
# Making API Request...
# Succesful!
# ----------------------------------------------------------------------------------
# Actual Batch: 688. Number of Tracks retrieved: 34400. Tracks Remaining: 43
#          artist_name                                  track_name  \
# 0      Missy Elliott  Lose Control (feat. Ciara & Fat Man Scoop)
# 0      Missy Elliott                                     Work It
# 0      Missy Elliott                             Get Ur Freak On
# 0      Missy Elliott             One Minute Man (feat. Ludacris)
# 0      Missy Elliott                             Get Ur Freak On
# ...              ...                                         ...
# 34435          Layla                                  Oh My Love
# 34437        Aayushi                               Diamond Child
# 34438          Jon D                                I Don't Know
# 34439      Big Words                                  The Answer
# 34441      Jon Jason                                Good Feeling
#
#                                   album_uri  \
# 0      spotify:album:6vV5UrXcfyQD1wu4Qo2I9K
# 0      spotify:album:6DeU398qrJ1bLuryetSmup
# 0      spotify:album:6epR3D622KWsnuHye7ApOl
# 0      spotify:album:20t54K6C80QQH7vbcpfJcP
# 0      spotify:album:20t54K6C80QQH7vbcpfJcP
# ...                                     ...
# 34435  spotify:album:4eTl12dc7uQXvgDhtMgW5p
# 34437  spotify:album:5bWtDTwS9llWcnhmgRkav3
# 34438  spotify:album:2KEQtuVl1cYsTYtVRUrNVi
# 34439  spotify:album:5jrsRHRAmetu5e7RRBoxj7
# 34441  spotify:album:2dZ7oVNQBeLlpoUYfbEsJP
#
#                                album_name  danceability  energy  key  \
# 0                            The Cookbook         0.904   0.813    4
# 0                      Under Construction         0.884   0.677    1
# 0                            Respect M.E.         0.794   0.805    0
# 0                   Miss E...So Addictive         0.622   0.669    9
# 0                   Miss E...So Addictive         0.797   0.750    0
# ...                                   ...           ...     ...  ...
# 34435                   Yellow Circles EP         0.434   0.279    8
# 34437                       Diamond Child         0.416   0.394   11
# 34438                               Roots         0.669   0.228    2
# 34439  Hollywood, a Beautiful Coincidence         0.493   0.727    1
# 34441                        Good Feeling         0.509   0.286    8
#
#        loudness  mode  speechiness  ...  instrumentalness  liveness  valence  \
# 0        -7.105     0       0.1210  ...          0.006970    0.0471    0.810
# 0        -5.603     1       0.2830  ...          0.000000    0.0732    0.584
# 0        -6.554     1       0.2300  ...          0.122000    0.0952    0.658
# 0        -8.419     1       0.3290  ...          0.000003    0.1520    0.570
# 0        -9.369     1       0.2470  ...          0.108000    0.0950    0.740
# ...         ...   ...          ...  ...               ...       ...      ...
# 34435   -11.947     1       0.0465  ...          0.042400    0.1330    0.157
# 34437    -9.269     1       0.0641  ...          0.001550    0.0988    0.131
# 34438   -12.119     1       0.0690  ...          0.065000    0.0944    0.402
# 34439    -5.031     1       0.2170  ...          0.000000    0.1290    0.289
# 34441   -14.722     1       0.1230  ...          0.000012    0.1310    0.259
#
#          tempo  duration_ms  time_signature  \
# 0      125.461       226864               4
# 0      101.868       263227               4
# 0      177.799       236933               4
# 0       93.839       252987               4
# 0      177.870       211120               4
# ...        ...          ...             ...
# 34435  145.264       203676               3
# 34437   81.988       237008               4
# 34438   83.024       189184               4
# 34439   73.259       263680               4
# 34441  121.633       194720               4
#
#                                   track_uri  \
# 0      spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 0      spotify:track:3jagJCUbdqhDSPuxP8cAqF
# 0      spotify:track:3XplJgPz8VjbDzbGwGgZdq
# 0      spotify:track:0jG92AlXau21qgCQRxGLic
# 0      spotify:track:6zsk6uF3MxfIeHPlubKBvR
# ...                                     ...
# 34435  spotify:track:0KMrYUEfexgam36li6d9F0
# 34437  spotify:track:1msfqzqHggvi1mlCT4Z7O5
# 34438  spotify:track:3uCHI1gfOUL5j5swEh0TcH
# 34439  spotify:track:0P1oO2gREMYUCoOkzYAyFu
# 34441  spotify:track:4Ri5TTUgjM96tbQZd5Ua7V
#
#                                                   genres artist_popularity  \
# 0      [dance pop, hip hop, hip pop, neo soul, pop ra...                72
# 0      [dance pop, hip hop, hip pop, neo soul, pop ra...                72
# 0      [dance pop, hip hop, hip pop, neo soul, pop ra...                72
# 0      [dance pop, hip hop, hip pop, neo soul, pop ra...                72
# 0      [dance pop, hip hop, hip pop, neo soul, pop ra...                72
# ...                                                  ...               ...
# 34435                                [indie anthem-folk]                23
# 34437                                                 []                22
# 34438                                      [channel pop]                41
# 34439                                   [australian r&b]                41
# 34441                                                 []                 2
#
#                                   artist_uri
# 0      spotify:artist:2wIVse2owClT7go1WT98tk
# 0      spotify:artist:2wIVse2owClT7go1WT98tk
# 0      spotify:artist:2wIVse2owClT7go1WT98tk
# 0      spotify:artist:2wIVse2owClT7go1WT98tk
# 0      spotify:artist:2wIVse2owClT7go1WT98tk
# ...                                      ...
# 34435  spotify:artist:04BsVprJtIhl2C4fgPEz4W
# 34437  spotify:artist:1r2kTJ27zuaEoXasQT5NDd
# 34438  spotify:artist:5HCypjplgh5uQezvBpOfXN
# 34439  spotify:artist:0sHN89qak07mnug3LVVjzP
# 34441  spotify:artist:77bNdkKYBBmc30CisCA6tE
#
# [34323 rows x 21 columns]

# %% [markdown]
# ### Requesting to Spotify's API the data of every Artist in the dataset

# %%
def extract_track_data(df, batch_size = 50, verbose = True):
  # Set 'track_uri' as the index for efficient merging
  df = df.set_index('track_uri')
  
  # Get a list of all the track URIs in the DataFrame
  track_uris = df.index.to_list()
  
  # Calculate the number of batches needed based on batch size
  num_batches = math.ceil(len(track_uris) / batch_size)
  
  # Initialize an empty list to store the results
  audio_features = []
  
  # Make requests to the Spotify API in batches of size 'batch_size'
  for i in range(num_batches):
    # Calculate the start and end indices of the current batch
    start_idx = i * batch_size
    end_idx = min((i + 1) * batch_size, len(track_uris))
    
    # Extract the track URIs for the current batch
    track_batch_uris = track_uris[start_idx:end_idx]
    
    # Request audio features and track's data for the current batch of track URIs from the Spotify API
    track_batch_data = sp.tracks(track_batch_uris)['tracks']
    
    # Extend the list of audio features with the results of the current batch
    audio_features.extend(track_batch_data)
    
    #If Verbose is Enabled, the function will print current API requests status in terminal.
    if verbose:
      print(f'----------------------------------------------------------------------------------')
      print(f'Actual Batch: {i}. Number of Tracks retrieved: {i * batch_size}. Tracks Remaining: {len(df) - i * batch_size}')

  # Convert audio_features list to DataFrame
  features_df = pd.DataFrame([af for af in audio_features if af is not None])
  
  # Remove duplicates based on the 'uri' column
  features_df = features_df.drop_duplicates(subset='uri')
  
  # Extract 'release_date' from the dictionaries within 'album' column
  features_df['release_date'] = features_df['album'].apply(lambda x: x['release_date'])
  
  # Drop unnecesary columns
  drop_columns = ['disc_number',	'explicit',	'external_ids',	'external_urls',	'href',	'is_local',	'name', 'artists', 'available_markets',	'id', 'preview_url',	'track_number',	'type', 'duration_ms', 'album']
  features_df = features_df.drop(drop_columns, axis = 1)
  
  # Merge audio features DataFrame with the final_df based on 'track_uri' index
  final_df = df.merge(features_df, left_index = True, right_on= 'uri')
  final_df = final_df.rename(columns = {'uri' : 'track_uri', 'popularity' : 'track_popularity'})
  
  return final_df

# %%
track_data_df = extract_track_data(artist_df)
track_data_df
# Out:
# ----------------------------------------------------------------------------------
# Actual Batch: 0. Number of Tracks retrieved: 0. Tracks Remaining: 34323
# ----------------------------------------------------------------------------------
# Actual Batch: 1. Number of Tracks retrieved: 50. Tracks Remaining: 34273
# ----------------------------------------------------------------------------------
# Actual Batch: 2. Number of Tracks retrieved: 100. Tracks Remaining: 34223
# ----------------------------------------------------------------------------------
# Actual Batch: 3. Number of Tracks retrieved: 150. Tracks Remaining: 34173
# ----------------------------------------------------------------------------------
# Actual Batch: 4. Number of Tracks retrieved: 200. Tracks Remaining: 34123
# ----------------------------------------------------------------------------------
# Actual Batch: 5. Number of Tracks retrieved: 250. Tracks Remaining: 34073
# ----------------------------------------------------------------------------------
# Actual Batch: 6. Number of Tracks retrieved: 300. Tracks Remaining: 34023
# ----------------------------------------------------------------------------------
# Actual Batch: 7. Number of Tracks retrieved: 350. Tracks Remaining: 33973
# ----------------------------------------------------------------------------------
# Actual Batch: 8. Number of Tracks retrieved: 400. Tracks Remaining: 33923
# ----------------------------------------------------------------------------------
# Actual Batch: 9. Number of Tracks retrieved: 450. Tracks Remaining: 33873
# ----------------------------------------------------------------------------------
# Actual Batch: 10. Number of Tracks retrieved: 500. Tracks Remaining: 33823
# ----------------------------------------------------------------------------------
# Actual Batch: 11. Number of Tracks retrieved: 550. Tracks Remaining: 33773
# ----------------------------------------------------------------------------------
# Actual Batch: 12. Number of Tracks retrieved: 600. Tracks Remaining: 33723
# ----------------------------------------------------------------------------------
# Actual Batch: 13. Number of Tracks retrieved: 650. Tracks Remaining: 33673
# ----------------------------------------------------------------------------------
# Actual Batch: 14. Number of Tracks retrieved: 700. Tracks Remaining: 33623
# ----------------------------------------------------------------------------------
# Actual Batch: 15. Number of Tracks retrieved: 750. Tracks Remaining: 33573
# ----------------------------------------------------------------------------------
# Actual Batch: 16. Number of Tracks retrieved: 800. Tracks Remaining: 33523
# ----------------------------------------------------------------------------------
# Actual Batch: 17. Number of Tracks retrieved: 850. Tracks Remaining: 33473
# ----------------------------------------------------------------------------------
# Actual Batch: 18. Number of Tracks retrieved: 900. Tracks Remaining: 33423
# ----------------------------------------------------------------------------------
# Actual Batch: 19. Number of Tracks retrieved: 950. Tracks Remaining: 33373
# ----------------------------------------------------------------------------------
# Actual Batch: 20. Number of Tracks retrieved: 1000. Tracks Remaining: 33323
# ----------------------------------------------------------------------------------
# Actual Batch: 21. Number of Tracks retrieved: 1050. Tracks Remaining: 33273
# ----------------------------------------------------------------------------------
# Actual Batch: 22. Number of Tracks retrieved: 1100. Tracks Remaining: 33223
# ----------------------------------------------------------------------------------
# Actual Batch: 23. Number of Tracks retrieved: 1150. Tracks Remaining: 33173
# ----------------------------------------------------------------------------------
# Actual Batch: 24. Number of Tracks retrieved: 1200. Tracks Remaining: 33123
# ----------------------------------------------------------------------------------
# Actual Batch: 25. Number of Tracks retrieved: 1250. Tracks Remaining: 33073
# ----------------------------------------------------------------------------------
# Actual Batch: 26. Number of Tracks retrieved: 1300. Tracks Remaining: 33023
# ----------------------------------------------------------------------------------
# Actual Batch: 27. Number of Tracks retrieved: 1350. Tracks Remaining: 32973
# ----------------------------------------------------------------------------------
# Actual Batch: 28. Number of Tracks retrieved: 1400. Tracks Remaining: 32923
# ----------------------------------------------------------------------------------
# Actual Batch: 29. Number of Tracks retrieved: 1450. Tracks Remaining: 32873
# ----------------------------------------------------------------------------------
# Actual Batch: 30. Number of Tracks retrieved: 1500. Tracks Remaining: 32823
# ----------------------------------------------------------------------------------
# Actual Batch: 31. Number of Tracks retrieved: 1550. Tracks Remaining: 32773
# ----------------------------------------------------------------------------------
# Actual Batch: 32. Number of Tracks retrieved: 1600. Tracks Remaining: 32723
# ----------------------------------------------------------------------------------
# Actual Batch: 33. Number of Tracks retrieved: 1650. Tracks Remaining: 32673
# ----------------------------------------------------------------------------------
# Actual Batch: 34. Number of Tracks retrieved: 1700. Tracks Remaining: 32623
# ----------------------------------------------------------------------------------
# Actual Batch: 35. Number of Tracks retrieved: 1750. Tracks Remaining: 32573
# ----------------------------------------------------------------------------------
# Actual Batch: 36. Number of Tracks retrieved: 1800. Tracks Remaining: 32523
# ----------------------------------------------------------------------------------
# Actual Batch: 37. Number of Tracks retrieved: 1850. Tracks Remaining: 32473
# ----------------------------------------------------------------------------------
# Actual Batch: 38. Number of Tracks retrieved: 1900. Tracks Remaining: 32423
# ----------------------------------------------------------------------------------
# Actual Batch: 39. Number of Tracks retrieved: 1950. Tracks Remaining: 32373
# ----------------------------------------------------------------------------------
# Actual Batch: 40. Number of Tracks retrieved: 2000. Tracks Remaining: 32323
# ----------------------------------------------------------------------------------
# Actual Batch: 41. Number of Tracks retrieved: 2050. Tracks Remaining: 32273
# ----------------------------------------------------------------------------------
# Actual Batch: 42. Number of Tracks retrieved: 2100. Tracks Remaining: 32223
# ----------------------------------------------------------------------------------
# Actual Batch: 43. Number of Tracks retrieved: 2150. Tracks Remaining: 32173
# ----------------------------------------------------------------------------------
# Actual Batch: 44. Number of Tracks retrieved: 2200. Tracks Remaining: 32123
# ----------------------------------------------------------------------------------
# Actual Batch: 45. Number of Tracks retrieved: 2250. Tracks Remaining: 32073
# ----------------------------------------------------------------------------------
# Actual Batch: 46. Number of Tracks retrieved: 2300. Tracks Remaining: 32023
# ----------------------------------------------------------------------------------
# Actual Batch: 47. Number of Tracks retrieved: 2350. Tracks Remaining: 31973
# ----------------------------------------------------------------------------------
# Actual Batch: 48. Number of Tracks retrieved: 2400. Tracks Remaining: 31923
# ----------------------------------------------------------------------------------
# Actual Batch: 49. Number of Tracks retrieved: 2450. Tracks Remaining: 31873
# ----------------------------------------------------------------------------------
# Actual Batch: 50. Number of Tracks retrieved: 2500. Tracks Remaining: 31823
# ----------------------------------------------------------------------------------
# Actual Batch: 51. Number of Tracks retrieved: 2550. Tracks Remaining: 31773
# ----------------------------------------------------------------------------------
# Actual Batch: 52. Number of Tracks retrieved: 2600. Tracks Remaining: 31723
# ----------------------------------------------------------------------------------
# Actual Batch: 53. Number of Tracks retrieved: 2650. Tracks Remaining: 31673
# ----------------------------------------------------------------------------------
# Actual Batch: 54. Number of Tracks retrieved: 2700. Tracks Remaining: 31623
# ----------------------------------------------------------------------------------
# Actual Batch: 55. Number of Tracks retrieved: 2750. Tracks Remaining: 31573
# ----------------------------------------------------------------------------------
# Actual Batch: 56. Number of Tracks retrieved: 2800. Tracks Remaining: 31523
# ----------------------------------------------------------------------------------
# Actual Batch: 57. Number of Tracks retrieved: 2850. Tracks Remaining: 31473
# ----------------------------------------------------------------------------------
# Actual Batch: 58. Number of Tracks retrieved: 2900. Tracks Remaining: 31423
# ----------------------------------------------------------------------------------
# Actual Batch: 59. Number of Tracks retrieved: 2950. Tracks Remaining: 31373
# ----------------------------------------------------------------------------------
# Actual Batch: 60. Number of Tracks retrieved: 3000. Tracks Remaining: 31323
# ----------------------------------------------------------------------------------
# Actual Batch: 61. Number of Tracks retrieved: 3050. Tracks Remaining: 31273
# ----------------------------------------------------------------------------------
# Actual Batch: 62. Number of Tracks retrieved: 3100. Tracks Remaining: 31223
# ----------------------------------------------------------------------------------
# Actual Batch: 63. Number of Tracks retrieved: 3150. Tracks Remaining: 31173
# ----------------------------------------------------------------------------------
# Actual Batch: 64. Number of Tracks retrieved: 3200. Tracks Remaining: 31123
# ----------------------------------------------------------------------------------
# Actual Batch: 65. Number of Tracks retrieved: 3250. Tracks Remaining: 31073
# ----------------------------------------------------------------------------------
# Actual Batch: 66. Number of Tracks retrieved: 3300. Tracks Remaining: 31023
# ----------------------------------------------------------------------------------
# Actual Batch: 67. Number of Tracks retrieved: 3350. Tracks Remaining: 30973
# ----------------------------------------------------------------------------------
# Actual Batch: 68. Number of Tracks retrieved: 3400. Tracks Remaining: 30923
# ----------------------------------------------------------------------------------
# Actual Batch: 69. Number of Tracks retrieved: 3450. Tracks Remaining: 30873
# ----------------------------------------------------------------------------------
# Actual Batch: 70. Number of Tracks retrieved: 3500. Tracks Remaining: 30823
# ----------------------------------------------------------------------------------
# Actual Batch: 71. Number of Tracks retrieved: 3550. Tracks Remaining: 30773
# ----------------------------------------------------------------------------------
# Actual Batch: 72. Number of Tracks retrieved: 3600. Tracks Remaining: 30723
# ----------------------------------------------------------------------------------
# Actual Batch: 73. Number of Tracks retrieved: 3650. Tracks Remaining: 30673
# ----------------------------------------------------------------------------------
# Actual Batch: 74. Number of Tracks retrieved: 3700. Tracks Remaining: 30623
# ----------------------------------------------------------------------------------
# Actual Batch: 75. Number of Tracks retrieved: 3750. Tracks Remaining: 30573
# ----------------------------------------------------------------------------------
# Actual Batch: 76. Number of Tracks retrieved: 3800. Tracks Remaining: 30523
# ----------------------------------------------------------------------------------
# Actual Batch: 77. Number of Tracks retrieved: 3850. Tracks Remaining: 30473
# ----------------------------------------------------------------------------------
# Actual Batch: 78. Number of Tracks retrieved: 3900. Tracks Remaining: 30423
# ----------------------------------------------------------------------------------
# Actual Batch: 79. Number of Tracks retrieved: 3950. Tracks Remaining: 30373
# ----------------------------------------------------------------------------------
# Actual Batch: 80. Number of Tracks retrieved: 4000. Tracks Remaining: 30323
# ----------------------------------------------------------------------------------
# Actual Batch: 81. Number of Tracks retrieved: 4050. Tracks Remaining: 30273
# ----------------------------------------------------------------------------------
# Actual Batch: 82. Number of Tracks retrieved: 4100. Tracks Remaining: 30223
# ----------------------------------------------------------------------------------
# Actual Batch: 83. Number of Tracks retrieved: 4150. Tracks Remaining: 30173
# ----------------------------------------------------------------------------------
# Actual Batch: 84. Number of Tracks retrieved: 4200. Tracks Remaining: 30123
# ----------------------------------------------------------------------------------
# Actual Batch: 85. Number of Tracks retrieved: 4250. Tracks Remaining: 30073
# ----------------------------------------------------------------------------------
# Actual Batch: 86. Number of Tracks retrieved: 4300. Tracks Remaining: 30023
# ----------------------------------------------------------------------------------
# Actual Batch: 87. Number of Tracks retrieved: 4350. Tracks Remaining: 29973
# ----------------------------------------------------------------------------------
# Actual Batch: 88. Number of Tracks retrieved: 4400. Tracks Remaining: 29923
# ----------------------------------------------------------------------------------
# Actual Batch: 89. Number of Tracks retrieved: 4450. Tracks Remaining: 29873
# ----------------------------------------------------------------------------------
# Actual Batch: 90. Number of Tracks retrieved: 4500. Tracks Remaining: 29823
# ----------------------------------------------------------------------------------
# Actual Batch: 91. Number of Tracks retrieved: 4550. Tracks Remaining: 29773
# ----------------------------------------------------------------------------------
# Actual Batch: 92. Number of Tracks retrieved: 4600. Tracks Remaining: 29723
# ----------------------------------------------------------------------------------
# Actual Batch: 93. Number of Tracks retrieved: 4650. Tracks Remaining: 29673
# ----------------------------------------------------------------------------------
# Actual Batch: 94. Number of Tracks retrieved: 4700. Tracks Remaining: 29623
# ----------------------------------------------------------------------------------
# Actual Batch: 95. Number of Tracks retrieved: 4750. Tracks Remaining: 29573
# ----------------------------------------------------------------------------------
# Actual Batch: 96. Number of Tracks retrieved: 4800. Tracks Remaining: 29523
# ----------------------------------------------------------------------------------
# Actual Batch: 97. Number of Tracks retrieved: 4850. Tracks Remaining: 29473
# ----------------------------------------------------------------------------------
# Actual Batch: 98. Number of Tracks retrieved: 4900. Tracks Remaining: 29423
# ----------------------------------------------------------------------------------
# Actual Batch: 99. Number of Tracks retrieved: 4950. Tracks Remaining: 29373
# ----------------------------------------------------------------------------------
# Actual Batch: 100. Number of Tracks retrieved: 5000. Tracks Remaining: 29323
# ----------------------------------------------------------------------------------
# Actual Batch: 101. Number of Tracks retrieved: 5050. Tracks Remaining: 29273
# ----------------------------------------------------------------------------------
# Actual Batch: 102. Number of Tracks retrieved: 5100. Tracks Remaining: 29223
# ----------------------------------------------------------------------------------
# Actual Batch: 103. Number of Tracks retrieved: 5150. Tracks Remaining: 29173
# ----------------------------------------------------------------------------------
# Actual Batch: 104. Number of Tracks retrieved: 5200. Tracks Remaining: 29123
# ----------------------------------------------------------------------------------
# Actual Batch: 105. Number of Tracks retrieved: 5250. Tracks Remaining: 29073
# ----------------------------------------------------------------------------------
# Actual Batch: 106. Number of Tracks retrieved: 5300. Tracks Remaining: 29023
# ----------------------------------------------------------------------------------
# Actual Batch: 107. Number of Tracks retrieved: 5350. Tracks Remaining: 28973
# ----------------------------------------------------------------------------------
# Actual Batch: 108. Number of Tracks retrieved: 5400. Tracks Remaining: 28923
# ----------------------------------------------------------------------------------
# Actual Batch: 109. Number of Tracks retrieved: 5450. Tracks Remaining: 28873
# ----------------------------------------------------------------------------------
# Actual Batch: 110. Number of Tracks retrieved: 5500. Tracks Remaining: 28823
# ----------------------------------------------------------------------------------
# Actual Batch: 111. Number of Tracks retrieved: 5550. Tracks Remaining: 28773
# ----------------------------------------------------------------------------------
# Actual Batch: 112. Number of Tracks retrieved: 5600. Tracks Remaining: 28723
# ----------------------------------------------------------------------------------
# Actual Batch: 113. Number of Tracks retrieved: 5650. Tracks Remaining: 28673
# ----------------------------------------------------------------------------------
# Actual Batch: 114. Number of Tracks retrieved: 5700. Tracks Remaining: 28623
# ----------------------------------------------------------------------------------
# Actual Batch: 115. Number of Tracks retrieved: 5750. Tracks Remaining: 28573
# ----------------------------------------------------------------------------------
# Actual Batch: 116. Number of Tracks retrieved: 5800. Tracks Remaining: 28523
# ----------------------------------------------------------------------------------
# Actual Batch: 117. Number of Tracks retrieved: 5850. Tracks Remaining: 28473
# ----------------------------------------------------------------------------------
# Actual Batch: 118. Number of Tracks retrieved: 5900. Tracks Remaining: 28423
# ----------------------------------------------------------------------------------
# Actual Batch: 119. Number of Tracks retrieved: 5950. Tracks Remaining: 28373
# ----------------------------------------------------------------------------------
# Actual Batch: 120. Number of Tracks retrieved: 6000. Tracks Remaining: 28323
# ----------------------------------------------------------------------------------
# Actual Batch: 121. Number of Tracks retrieved: 6050. Tracks Remaining: 28273
# ----------------------------------------------------------------------------------
# Actual Batch: 122. Number of Tracks retrieved: 6100. Tracks Remaining: 28223
# ----------------------------------------------------------------------------------
# Actual Batch: 123. Number of Tracks retrieved: 6150. Tracks Remaining: 28173
# ----------------------------------------------------------------------------------
# Actual Batch: 124. Number of Tracks retrieved: 6200. Tracks Remaining: 28123
# ----------------------------------------------------------------------------------
# Actual Batch: 125. Number of Tracks retrieved: 6250. Tracks Remaining: 28073
# ----------------------------------------------------------------------------------
# Actual Batch: 126. Number of Tracks retrieved: 6300. Tracks Remaining: 28023
# ----------------------------------------------------------------------------------
# Actual Batch: 127. Number of Tracks retrieved: 6350. Tracks Remaining: 27973
# ----------------------------------------------------------------------------------
# Actual Batch: 128. Number of Tracks retrieved: 6400. Tracks Remaining: 27923
# ----------------------------------------------------------------------------------
# Actual Batch: 129. Number of Tracks retrieved: 6450. Tracks Remaining: 27873
# ----------------------------------------------------------------------------------
# Actual Batch: 130. Number of Tracks retrieved: 6500. Tracks Remaining: 27823
# ----------------------------------------------------------------------------------
# Actual Batch: 131. Number of Tracks retrieved: 6550. Tracks Remaining: 27773
# ----------------------------------------------------------------------------------
# Actual Batch: 132. Number of Tracks retrieved: 6600. Tracks Remaining: 27723
# ----------------------------------------------------------------------------------
# Actual Batch: 133. Number of Tracks retrieved: 6650. Tracks Remaining: 27673
# ----------------------------------------------------------------------------------
# Actual Batch: 134. Number of Tracks retrieved: 6700. Tracks Remaining: 27623
# ----------------------------------------------------------------------------------
# Actual Batch: 135. Number of Tracks retrieved: 6750. Tracks Remaining: 27573
# ----------------------------------------------------------------------------------
# Actual Batch: 136. Number of Tracks retrieved: 6800. Tracks Remaining: 27523
# ----------------------------------------------------------------------------------
# Actual Batch: 137. Number of Tracks retrieved: 6850. Tracks Remaining: 27473
# ----------------------------------------------------------------------------------
# Actual Batch: 138. Number of Tracks retrieved: 6900. Tracks Remaining: 27423
# ----------------------------------------------------------------------------------
# Actual Batch: 139. Number of Tracks retrieved: 6950. Tracks Remaining: 27373
# ----------------------------------------------------------------------------------
# Actual Batch: 140. Number of Tracks retrieved: 7000. Tracks Remaining: 27323
# ----------------------------------------------------------------------------------
# Actual Batch: 141. Number of Tracks retrieved: 7050. Tracks Remaining: 27273
# ----------------------------------------------------------------------------------
# Actual Batch: 142. Number of Tracks retrieved: 7100. Tracks Remaining: 27223
# ----------------------------------------------------------------------------------
# Actual Batch: 143. Number of Tracks retrieved: 7150. Tracks Remaining: 27173
# ----------------------------------------------------------------------------------
# Actual Batch: 144. Number of Tracks retrieved: 7200. Tracks Remaining: 27123
# ----------------------------------------------------------------------------------
# Actual Batch: 145. Number of Tracks retrieved: 7250. Tracks Remaining: 27073
# ----------------------------------------------------------------------------------
# Actual Batch: 146. Number of Tracks retrieved: 7300. Tracks Remaining: 27023
# ----------------------------------------------------------------------------------
# Actual Batch: 147. Number of Tracks retrieved: 7350. Tracks Remaining: 26973
# ----------------------------------------------------------------------------------
# Actual Batch: 148. Number of Tracks retrieved: 7400. Tracks Remaining: 26923
# ----------------------------------------------------------------------------------
# Actual Batch: 149. Number of Tracks retrieved: 7450. Tracks Remaining: 26873
# ----------------------------------------------------------------------------------
# Actual Batch: 150. Number of Tracks retrieved: 7500. Tracks Remaining: 26823
# ----------------------------------------------------------------------------------
# Actual Batch: 151. Number of Tracks retrieved: 7550. Tracks Remaining: 26773
# ----------------------------------------------------------------------------------
# Actual Batch: 152. Number of Tracks retrieved: 7600. Tracks Remaining: 26723
# ----------------------------------------------------------------------------------
# Actual Batch: 153. Number of Tracks retrieved: 7650. Tracks Remaining: 26673
# ----------------------------------------------------------------------------------
# Actual Batch: 154. Number of Tracks retrieved: 7700. Tracks Remaining: 26623
# ----------------------------------------------------------------------------------
# Actual Batch: 155. Number of Tracks retrieved: 7750. Tracks Remaining: 26573
# ----------------------------------------------------------------------------------
# Actual Batch: 156. Number of Tracks retrieved: 7800. Tracks Remaining: 26523
# ----------------------------------------------------------------------------------
# Actual Batch: 157. Number of Tracks retrieved: 7850. Tracks Remaining: 26473
# ----------------------------------------------------------------------------------
# Actual Batch: 158. Number of Tracks retrieved: 7900. Tracks Remaining: 26423
# ----------------------------------------------------------------------------------
# Actual Batch: 159. Number of Tracks retrieved: 7950. Tracks Remaining: 26373
# ----------------------------------------------------------------------------------
# Actual Batch: 160. Number of Tracks retrieved: 8000. Tracks Remaining: 26323
# ----------------------------------------------------------------------------------
# Actual Batch: 161. Number of Tracks retrieved: 8050. Tracks Remaining: 26273
# ----------------------------------------------------------------------------------
# Actual Batch: 162. Number of Tracks retrieved: 8100. Tracks Remaining: 26223
# ----------------------------------------------------------------------------------
# Actual Batch: 163. Number of Tracks retrieved: 8150. Tracks Remaining: 26173
# ----------------------------------------------------------------------------------
# Actual Batch: 164. Number of Tracks retrieved: 8200. Tracks Remaining: 26123
# ----------------------------------------------------------------------------------
# Actual Batch: 165. Number of Tracks retrieved: 8250. Tracks Remaining: 26073
# ----------------------------------------------------------------------------------
# Actual Batch: 166. Number of Tracks retrieved: 8300. Tracks Remaining: 26023
# ----------------------------------------------------------------------------------
# Actual Batch: 167. Number of Tracks retrieved: 8350. Tracks Remaining: 25973
# ----------------------------------------------------------------------------------
# Actual Batch: 168. Number of Tracks retrieved: 8400. Tracks Remaining: 25923
# ----------------------------------------------------------------------------------
# Actual Batch: 169. Number of Tracks retrieved: 8450. Tracks Remaining: 25873
# ----------------------------------------------------------------------------------
# Actual Batch: 170. Number of Tracks retrieved: 8500. Tracks Remaining: 25823
# ----------------------------------------------------------------------------------
# Actual Batch: 171. Number of Tracks retrieved: 8550. Tracks Remaining: 25773
# ----------------------------------------------------------------------------------
# Actual Batch: 172. Number of Tracks retrieved: 8600. Tracks Remaining: 25723
# ----------------------------------------------------------------------------------
# Actual Batch: 173. Number of Tracks retrieved: 8650. Tracks Remaining: 25673
# ----------------------------------------------------------------------------------
# Actual Batch: 174. Number of Tracks retrieved: 8700. Tracks Remaining: 25623
# ----------------------------------------------------------------------------------
# Actual Batch: 175. Number of Tracks retrieved: 8750. Tracks Remaining: 25573
# ----------------------------------------------------------------------------------
# Actual Batch: 176. Number of Tracks retrieved: 8800. Tracks Remaining: 25523
# ----------------------------------------------------------------------------------
# Actual Batch: 177. Number of Tracks retrieved: 8850. Tracks Remaining: 25473
# ----------------------------------------------------------------------------------
# Actual Batch: 178. Number of Tracks retrieved: 8900. Tracks Remaining: 25423
# ----------------------------------------------------------------------------------
# Actual Batch: 179. Number of Tracks retrieved: 8950. Tracks Remaining: 25373
# ----------------------------------------------------------------------------------
# Actual Batch: 180. Number of Tracks retrieved: 9000. Tracks Remaining: 25323
# ----------------------------------------------------------------------------------
# Actual Batch: 181. Number of Tracks retrieved: 9050. Tracks Remaining: 25273
# ----------------------------------------------------------------------------------
# Actual Batch: 182. Number of Tracks retrieved: 9100. Tracks Remaining: 25223
# ----------------------------------------------------------------------------------
# Actual Batch: 183. Number of Tracks retrieved: 9150. Tracks Remaining: 25173
# ----------------------------------------------------------------------------------
# Actual Batch: 184. Number of Tracks retrieved: 9200. Tracks Remaining: 25123
# ----------------------------------------------------------------------------------
# Actual Batch: 185. Number of Tracks retrieved: 9250. Tracks Remaining: 25073
# ----------------------------------------------------------------------------------
# Actual Batch: 186. Number of Tracks retrieved: 9300. Tracks Remaining: 25023
# ----------------------------------------------------------------------------------
# Actual Batch: 187. Number of Tracks retrieved: 9350. Tracks Remaining: 24973
# ----------------------------------------------------------------------------------
# Actual Batch: 188. Number of Tracks retrieved: 9400. Tracks Remaining: 24923
# ----------------------------------------------------------------------------------
# Actual Batch: 189. Number of Tracks retrieved: 9450. Tracks Remaining: 24873
# ----------------------------------------------------------------------------------
# Actual Batch: 190. Number of Tracks retrieved: 9500. Tracks Remaining: 24823
# ----------------------------------------------------------------------------------
# Actual Batch: 191. Number of Tracks retrieved: 9550. Tracks Remaining: 24773
# ----------------------------------------------------------------------------------
# Actual Batch: 192. Number of Tracks retrieved: 9600. Tracks Remaining: 24723
# ----------------------------------------------------------------------------------
# Actual Batch: 193. Number of Tracks retrieved: 9650. Tracks Remaining: 24673
# ----------------------------------------------------------------------------------
# Actual Batch: 194. Number of Tracks retrieved: 9700. Tracks Remaining: 24623
# ----------------------------------------------------------------------------------
# Actual Batch: 195. Number of Tracks retrieved: 9750. Tracks Remaining: 24573
# ----------------------------------------------------------------------------------
# Actual Batch: 196. Number of Tracks retrieved: 9800. Tracks Remaining: 24523
# ----------------------------------------------------------------------------------
# Actual Batch: 197. Number of Tracks retrieved: 9850. Tracks Remaining: 24473
# ----------------------------------------------------------------------------------
# Actual Batch: 198. Number of Tracks retrieved: 9900. Tracks Remaining: 24423
# ----------------------------------------------------------------------------------
# Actual Batch: 199. Number of Tracks retrieved: 9950. Tracks Remaining: 24373
# ----------------------------------------------------------------------------------
# Actual Batch: 200. Number of Tracks retrieved: 10000. Tracks Remaining: 24323
# ----------------------------------------------------------------------------------
# Actual Batch: 201. Number of Tracks retrieved: 10050. Tracks Remaining: 24273
# ----------------------------------------------------------------------------------
# Actual Batch: 202. Number of Tracks retrieved: 10100. Tracks Remaining: 24223
# ----------------------------------------------------------------------------------
# Actual Batch: 203. Number of Tracks retrieved: 10150. Tracks Remaining: 24173
# ----------------------------------------------------------------------------------
# Actual Batch: 204. Number of Tracks retrieved: 10200. Tracks Remaining: 24123
# ----------------------------------------------------------------------------------
# Actual Batch: 205. Number of Tracks retrieved: 10250. Tracks Remaining: 24073
# ----------------------------------------------------------------------------------
# Actual Batch: 206. Number of Tracks retrieved: 10300. Tracks Remaining: 24023
# ----------------------------------------------------------------------------------
# Actual Batch: 207. Number of Tracks retrieved: 10350. Tracks Remaining: 23973
# ----------------------------------------------------------------------------------
# Actual Batch: 208. Number of Tracks retrieved: 10400. Tracks Remaining: 23923
# ----------------------------------------------------------------------------------
# Actual Batch: 209. Number of Tracks retrieved: 10450. Tracks Remaining: 23873
# ----------------------------------------------------------------------------------
# Actual Batch: 210. Number of Tracks retrieved: 10500. Tracks Remaining: 23823
# ----------------------------------------------------------------------------------
# Actual Batch: 211. Number of Tracks retrieved: 10550. Tracks Remaining: 23773
# ----------------------------------------------------------------------------------
# Actual Batch: 212. Number of Tracks retrieved: 10600. Tracks Remaining: 23723
# ----------------------------------------------------------------------------------
# Actual Batch: 213. Number of Tracks retrieved: 10650. Tracks Remaining: 23673
# ----------------------------------------------------------------------------------
# Actual Batch: 214. Number of Tracks retrieved: 10700. Tracks Remaining: 23623
# ----------------------------------------------------------------------------------
# Actual Batch: 215. Number of Tracks retrieved: 10750. Tracks Remaining: 23573
# ----------------------------------------------------------------------------------
# Actual Batch: 216. Number of Tracks retrieved: 10800. Tracks Remaining: 23523
# ----------------------------------------------------------------------------------
# Actual Batch: 217. Number of Tracks retrieved: 10850. Tracks Remaining: 23473
# ----------------------------------------------------------------------------------
# Actual Batch: 218. Number of Tracks retrieved: 10900. Tracks Remaining: 23423
# ----------------------------------------------------------------------------------
# Actual Batch: 219. Number of Tracks retrieved: 10950. Tracks Remaining: 23373
# ----------------------------------------------------------------------------------
# Actual Batch: 220. Number of Tracks retrieved: 11000. Tracks Remaining: 23323
# ----------------------------------------------------------------------------------
# Actual Batch: 221. Number of Tracks retrieved: 11050. Tracks Remaining: 23273
# ----------------------------------------------------------------------------------
# Actual Batch: 222. Number of Tracks retrieved: 11100. Tracks Remaining: 23223
# ----------------------------------------------------------------------------------
# Actual Batch: 223. Number of Tracks retrieved: 11150. Tracks Remaining: 23173
# ----------------------------------------------------------------------------------
# Actual Batch: 224. Number of Tracks retrieved: 11200. Tracks Remaining: 23123
# ----------------------------------------------------------------------------------
# Actual Batch: 225. Number of Tracks retrieved: 11250. Tracks Remaining: 23073
# ----------------------------------------------------------------------------------
# Actual Batch: 226. Number of Tracks retrieved: 11300. Tracks Remaining: 23023
# ----------------------------------------------------------------------------------
# Actual Batch: 227. Number of Tracks retrieved: 11350. Tracks Remaining: 22973
# ----------------------------------------------------------------------------------
# Actual Batch: 228. Number of Tracks retrieved: 11400. Tracks Remaining: 22923
# ----------------------------------------------------------------------------------
# Actual Batch: 229. Number of Tracks retrieved: 11450. Tracks Remaining: 22873
# ----------------------------------------------------------------------------------
# Actual Batch: 230. Number of Tracks retrieved: 11500. Tracks Remaining: 22823
# ----------------------------------------------------------------------------------
# Actual Batch: 231. Number of Tracks retrieved: 11550. Tracks Remaining: 22773
# ----------------------------------------------------------------------------------
# Actual Batch: 232. Number of Tracks retrieved: 11600. Tracks Remaining: 22723
# ----------------------------------------------------------------------------------
# Actual Batch: 233. Number of Tracks retrieved: 11650. Tracks Remaining: 22673
# ----------------------------------------------------------------------------------
# Actual Batch: 234. Number of Tracks retrieved: 11700. Tracks Remaining: 22623
# ----------------------------------------------------------------------------------
# Actual Batch: 235. Number of Tracks retrieved: 11750. Tracks Remaining: 22573
# ----------------------------------------------------------------------------------
# Actual Batch: 236. Number of Tracks retrieved: 11800. Tracks Remaining: 22523
# ----------------------------------------------------------------------------------
# Actual Batch: 237. Number of Tracks retrieved: 11850. Tracks Remaining: 22473
# ----------------------------------------------------------------------------------
# Actual Batch: 238. Number of Tracks retrieved: 11900. Tracks Remaining: 22423
# ----------------------------------------------------------------------------------
# Actual Batch: 239. Number of Tracks retrieved: 11950. Tracks Remaining: 22373
# ----------------------------------------------------------------------------------
# Actual Batch: 240. Number of Tracks retrieved: 12000. Tracks Remaining: 22323
# ----------------------------------------------------------------------------------
# Actual Batch: 241. Number of Tracks retrieved: 12050. Tracks Remaining: 22273
# ----------------------------------------------------------------------------------
# Actual Batch: 242. Number of Tracks retrieved: 12100. Tracks Remaining: 22223
# ----------------------------------------------------------------------------------
# Actual Batch: 243. Number of Tracks retrieved: 12150. Tracks Remaining: 22173
# ----------------------------------------------------------------------------------
# Actual Batch: 244. Number of Tracks retrieved: 12200. Tracks Remaining: 22123
# ----------------------------------------------------------------------------------
# Actual Batch: 245. Number of Tracks retrieved: 12250. Tracks Remaining: 22073
# ----------------------------------------------------------------------------------
# Actual Batch: 246. Number of Tracks retrieved: 12300. Tracks Remaining: 22023
# ----------------------------------------------------------------------------------
# Actual Batch: 247. Number of Tracks retrieved: 12350. Tracks Remaining: 21973
# ----------------------------------------------------------------------------------
# Actual Batch: 248. Number of Tracks retrieved: 12400. Tracks Remaining: 21923
# ----------------------------------------------------------------------------------
# Actual Batch: 249. Number of Tracks retrieved: 12450. Tracks Remaining: 21873
# ----------------------------------------------------------------------------------
# Actual Batch: 250. Number of Tracks retrieved: 12500. Tracks Remaining: 21823
# ----------------------------------------------------------------------------------
# Actual Batch: 251. Number of Tracks retrieved: 12550. Tracks Remaining: 21773
# ----------------------------------------------------------------------------------
# Actual Batch: 252. Number of Tracks retrieved: 12600. Tracks Remaining: 21723
# ----------------------------------------------------------------------------------
# Actual Batch: 253. Number of Tracks retrieved: 12650. Tracks Remaining: 21673
# ----------------------------------------------------------------------------------
# Actual Batch: 254. Number of Tracks retrieved: 12700. Tracks Remaining: 21623
# ----------------------------------------------------------------------------------
# Actual Batch: 255. Number of Tracks retrieved: 12750. Tracks Remaining: 21573
# ----------------------------------------------------------------------------------
# Actual Batch: 256. Number of Tracks retrieved: 12800. Tracks Remaining: 21523
# ----------------------------------------------------------------------------------
# Actual Batch: 257. Number of Tracks retrieved: 12850. Tracks Remaining: 21473
# ----------------------------------------------------------------------------------
# Actual Batch: 258. Number of Tracks retrieved: 12900. Tracks Remaining: 21423
# ----------------------------------------------------------------------------------
# Actual Batch: 259. Number of Tracks retrieved: 12950. Tracks Remaining: 21373
# ----------------------------------------------------------------------------------
# Actual Batch: 260. Number of Tracks retrieved: 13000. Tracks Remaining: 21323
# ----------------------------------------------------------------------------------
# Actual Batch: 261. Number of Tracks retrieved: 13050. Tracks Remaining: 21273
# ----------------------------------------------------------------------------------
# Actual Batch: 262. Number of Tracks retrieved: 13100. Tracks Remaining: 21223
# ----------------------------------------------------------------------------------
# Actual Batch: 263. Number of Tracks retrieved: 13150. Tracks Remaining: 21173
# ----------------------------------------------------------------------------------
# Actual Batch: 264. Number of Tracks retrieved: 13200. Tracks Remaining: 21123
# ----------------------------------------------------------------------------------
# Actual Batch: 265. Number of Tracks retrieved: 13250. Tracks Remaining: 21073
# ----------------------------------------------------------------------------------
# Actual Batch: 266. Number of Tracks retrieved: 13300. Tracks Remaining: 21023
# ----------------------------------------------------------------------------------
# Actual Batch: 267. Number of Tracks retrieved: 13350. Tracks Remaining: 20973
# ----------------------------------------------------------------------------------
# Actual Batch: 268. Number of Tracks retrieved: 13400. Tracks Remaining: 20923
# ----------------------------------------------------------------------------------
# Actual Batch: 269. Number of Tracks retrieved: 13450. Tracks Remaining: 20873
# ----------------------------------------------------------------------------------
# Actual Batch: 270. Number of Tracks retrieved: 13500. Tracks Remaining: 20823
# ----------------------------------------------------------------------------------
# Actual Batch: 271. Number of Tracks retrieved: 13550. Tracks Remaining: 20773
# ----------------------------------------------------------------------------------
# Actual Batch: 272. Number of Tracks retrieved: 13600. Tracks Remaining: 20723
# ----------------------------------------------------------------------------------
# Actual Batch: 273. Number of Tracks retrieved: 13650. Tracks Remaining: 20673
# ----------------------------------------------------------------------------------
# Actual Batch: 274. Number of Tracks retrieved: 13700. Tracks Remaining: 20623
# ----------------------------------------------------------------------------------
# Actual Batch: 275. Number of Tracks retrieved: 13750. Tracks Remaining: 20573
# ----------------------------------------------------------------------------------
# Actual Batch: 276. Number of Tracks retrieved: 13800. Tracks Remaining: 20523
# ----------------------------------------------------------------------------------
# Actual Batch: 277. Number of Tracks retrieved: 13850. Tracks Remaining: 20473
# ----------------------------------------------------------------------------------
# Actual Batch: 278. Number of Tracks retrieved: 13900. Tracks Remaining: 20423
# ----------------------------------------------------------------------------------
# Actual Batch: 279. Number of Tracks retrieved: 13950. Tracks Remaining: 20373
# ----------------------------------------------------------------------------------
# Actual Batch: 280. Number of Tracks retrieved: 14000. Tracks Remaining: 20323
# ----------------------------------------------------------------------------------
# Actual Batch: 281. Number of Tracks retrieved: 14050. Tracks Remaining: 20273
# ----------------------------------------------------------------------------------
# Actual Batch: 282. Number of Tracks retrieved: 14100. Tracks Remaining: 20223
# ----------------------------------------------------------------------------------
# Actual Batch: 283. Number of Tracks retrieved: 14150. Tracks Remaining: 20173
# ----------------------------------------------------------------------------------
# Actual Batch: 284. Number of Tracks retrieved: 14200. Tracks Remaining: 20123
# ----------------------------------------------------------------------------------
# Actual Batch: 285. Number of Tracks retrieved: 14250. Tracks Remaining: 20073
# ----------------------------------------------------------------------------------
# Actual Batch: 286. Number of Tracks retrieved: 14300. Tracks Remaining: 20023
# ----------------------------------------------------------------------------------
# Actual Batch: 287. Number of Tracks retrieved: 14350. Tracks Remaining: 19973
# ----------------------------------------------------------------------------------
# Actual Batch: 288. Number of Tracks retrieved: 14400. Tracks Remaining: 19923
# ----------------------------------------------------------------------------------
# Actual Batch: 289. Number of Tracks retrieved: 14450. Tracks Remaining: 19873
# ----------------------------------------------------------------------------------
# Actual Batch: 290. Number of Tracks retrieved: 14500. Tracks Remaining: 19823
# ----------------------------------------------------------------------------------
# Actual Batch: 291. Number of Tracks retrieved: 14550. Tracks Remaining: 19773
# ----------------------------------------------------------------------------------
# Actual Batch: 292. Number of Tracks retrieved: 14600. Tracks Remaining: 19723
# ----------------------------------------------------------------------------------
# Actual Batch: 293. Number of Tracks retrieved: 14650. Tracks Remaining: 19673
# ----------------------------------------------------------------------------------
# Actual Batch: 294. Number of Tracks retrieved: 14700. Tracks Remaining: 19623
# ----------------------------------------------------------------------------------
# Actual Batch: 295. Number of Tracks retrieved: 14750. Tracks Remaining: 19573
# ----------------------------------------------------------------------------------
# Actual Batch: 296. Number of Tracks retrieved: 14800. Tracks Remaining: 19523
# ----------------------------------------------------------------------------------
# Actual Batch: 297. Number of Tracks retrieved: 14850. Tracks Remaining: 19473
# ----------------------------------------------------------------------------------
# Actual Batch: 298. Number of Tracks retrieved: 14900. Tracks Remaining: 19423
# ----------------------------------------------------------------------------------
# Actual Batch: 299. Number of Tracks retrieved: 14950. Tracks Remaining: 19373
# ...
# Actual Batch: 623. Number of Tracks retrieved: 31150. Tracks Remaining: 3173
# ----------------------------------------------------------------------------------
# Actual Batch: 624. Number of Tracks retrieved: 31200. Tracks Remaining: 3123
# ----------------------------------------------------------------------------------
# Actual Batch: 625. Number of Tracks retrieved: 31250. Tracks Remaining: 3073
# ----------------------------------------------------------------------------------
# Actual Batch: 626. Number of Tracks retrieved: 31300. Tracks Remaining: 3023
# ----------------------------------------------------------------------------------
# Actual Batch: 627. Number of Tracks retrieved: 31350. Tracks Remaining: 2973
# ----------------------------------------------------------------------------------
# Actual Batch: 628. Number of Tracks retrieved: 31400. Tracks Remaining: 2923
# ----------------------------------------------------------------------------------
# Actual Batch: 629. Number of Tracks retrieved: 31450. Tracks Remaining: 2873
# ----------------------------------------------------------------------------------
# Actual Batch: 630. Number of Tracks retrieved: 31500. Tracks Remaining: 2823
# ----------------------------------------------------------------------------------
# Actual Batch: 631. Number of Tracks retrieved: 31550. Tracks Remaining: 2773
# ----------------------------------------------------------------------------------
# Actual Batch: 632. Number of Tracks retrieved: 31600. Tracks Remaining: 2723
# ----------------------------------------------------------------------------------
# Actual Batch: 633. Number of Tracks retrieved: 31650. Tracks Remaining: 2673
# ----------------------------------------------------------------------------------
# Actual Batch: 634. Number of Tracks retrieved: 31700. Tracks Remaining: 2623
# ----------------------------------------------------------------------------------
# Actual Batch: 635. Number of Tracks retrieved: 31750. Tracks Remaining: 2573
# ----------------------------------------------------------------------------------
# Actual Batch: 636. Number of Tracks retrieved: 31800. Tracks Remaining: 2523
# ----------------------------------------------------------------------------------
# Actual Batch: 637. Number of Tracks retrieved: 31850. Tracks Remaining: 2473
# ----------------------------------------------------------------------------------
# Actual Batch: 638. Number of Tracks retrieved: 31900. Tracks Remaining: 2423
# ----------------------------------------------------------------------------------
# Actual Batch: 639. Number of Tracks retrieved: 31950. Tracks Remaining: 2373
# ----------------------------------------------------------------------------------
# Actual Batch: 640. Number of Tracks retrieved: 32000. Tracks Remaining: 2323
# ----------------------------------------------------------------------------------
# Actual Batch: 641. Number of Tracks retrieved: 32050. Tracks Remaining: 2273
# ----------------------------------------------------------------------------------
# Actual Batch: 642. Number of Tracks retrieved: 32100. Tracks Remaining: 2223
# ----------------------------------------------------------------------------------
# Actual Batch: 643. Number of Tracks retrieved: 32150. Tracks Remaining: 2173
# ----------------------------------------------------------------------------------
# Actual Batch: 644. Number of Tracks retrieved: 32200. Tracks Remaining: 2123
# ----------------------------------------------------------------------------------
# Actual Batch: 645. Number of Tracks retrieved: 32250. Tracks Remaining: 2073
# ----------------------------------------------------------------------------------
# Actual Batch: 646. Number of Tracks retrieved: 32300. Tracks Remaining: 2023
# ----------------------------------------------------------------------------------
# Actual Batch: 647. Number of Tracks retrieved: 32350. Tracks Remaining: 1973
# ----------------------------------------------------------------------------------
# Actual Batch: 648. Number of Tracks retrieved: 32400. Tracks Remaining: 1923
# ----------------------------------------------------------------------------------
# Actual Batch: 649. Number of Tracks retrieved: 32450. Tracks Remaining: 1873
# ----------------------------------------------------------------------------------
# Actual Batch: 650. Number of Tracks retrieved: 32500. Tracks Remaining: 1823
# ----------------------------------------------------------------------------------
# Actual Batch: 651. Number of Tracks retrieved: 32550. Tracks Remaining: 1773
# ----------------------------------------------------------------------------------
# Actual Batch: 652. Number of Tracks retrieved: 32600. Tracks Remaining: 1723
# ----------------------------------------------------------------------------------
# Actual Batch: 653. Number of Tracks retrieved: 32650. Tracks Remaining: 1673
# ----------------------------------------------------------------------------------
# Actual Batch: 654. Number of Tracks retrieved: 32700. Tracks Remaining: 1623
# ----------------------------------------------------------------------------------
# Actual Batch: 655. Number of Tracks retrieved: 32750. Tracks Remaining: 1573
# ----------------------------------------------------------------------------------
# Actual Batch: 656. Number of Tracks retrieved: 32800. Tracks Remaining: 1523
# ----------------------------------------------------------------------------------
# Actual Batch: 657. Number of Tracks retrieved: 32850. Tracks Remaining: 1473
# ----------------------------------------------------------------------------------
# Actual Batch: 658. Number of Tracks retrieved: 32900. Tracks Remaining: 1423
# ----------------------------------------------------------------------------------
# Actual Batch: 659. Number of Tracks retrieved: 32950. Tracks Remaining: 1373
# ----------------------------------------------------------------------------------
# Actual Batch: 660. Number of Tracks retrieved: 33000. Tracks Remaining: 1323
# ----------------------------------------------------------------------------------
# Actual Batch: 661. Number of Tracks retrieved: 33050. Tracks Remaining: 1273
# ----------------------------------------------------------------------------------
# Actual Batch: 662. Number of Tracks retrieved: 33100. Tracks Remaining: 1223
# ----------------------------------------------------------------------------------
# Actual Batch: 663. Number of Tracks retrieved: 33150. Tracks Remaining: 1173
# ----------------------------------------------------------------------------------
# Actual Batch: 664. Number of Tracks retrieved: 33200. Tracks Remaining: 1123
# ----------------------------------------------------------------------------------
# Actual Batch: 665. Number of Tracks retrieved: 33250. Tracks Remaining: 1073
# ----------------------------------------------------------------------------------
# Actual Batch: 666. Number of Tracks retrieved: 33300. Tracks Remaining: 1023
# ----------------------------------------------------------------------------------
# Actual Batch: 667. Number of Tracks retrieved: 33350. Tracks Remaining: 973
# ----------------------------------------------------------------------------------
# Actual Batch: 668. Number of Tracks retrieved: 33400. Tracks Remaining: 923
# ----------------------------------------------------------------------------------
# Actual Batch: 669. Number of Tracks retrieved: 33450. Tracks Remaining: 873
# ----------------------------------------------------------------------------------
# Actual Batch: 670. Number of Tracks retrieved: 33500. Tracks Remaining: 823
# ----------------------------------------------------------------------------------
# Actual Batch: 671. Number of Tracks retrieved: 33550. Tracks Remaining: 773
# ----------------------------------------------------------------------------------
# Actual Batch: 672. Number of Tracks retrieved: 33600. Tracks Remaining: 723
# ----------------------------------------------------------------------------------
# Actual Batch: 673. Number of Tracks retrieved: 33650. Tracks Remaining: 673
# ----------------------------------------------------------------------------------
# Actual Batch: 674. Number of Tracks retrieved: 33700. Tracks Remaining: 623
# ----------------------------------------------------------------------------------
# Actual Batch: 675. Number of Tracks retrieved: 33750. Tracks Remaining: 573
# ----------------------------------------------------------------------------------
# Actual Batch: 676. Number of Tracks retrieved: 33800. Tracks Remaining: 523
# ----------------------------------------------------------------------------------
# Actual Batch: 677. Number of Tracks retrieved: 33850. Tracks Remaining: 473
# ----------------------------------------------------------------------------------
# Actual Batch: 678. Number of Tracks retrieved: 33900. Tracks Remaining: 423
# ----------------------------------------------------------------------------------
# Actual Batch: 679. Number of Tracks retrieved: 33950. Tracks Remaining: 373
# ----------------------------------------------------------------------------------
# Actual Batch: 680. Number of Tracks retrieved: 34000. Tracks Remaining: 323
# ----------------------------------------------------------------------------------
# Actual Batch: 681. Number of Tracks retrieved: 34050. Tracks Remaining: 273
# ----------------------------------------------------------------------------------
# Actual Batch: 682. Number of Tracks retrieved: 34100. Tracks Remaining: 223
# ----------------------------------------------------------------------------------
# Actual Batch: 683. Number of Tracks retrieved: 34150. Tracks Remaining: 173
# ----------------------------------------------------------------------------------
# Actual Batch: 684. Number of Tracks retrieved: 34200. Tracks Remaining: 123
# ----------------------------------------------------------------------------------
# Actual Batch: 685. Number of Tracks retrieved: 34250. Tracks Remaining: 73
# ----------------------------------------------------------------------------------
# Actual Batch: 686. Number of Tracks retrieved: 34300. Tracks Remaining: 23
#          artist_name                                  track_name  \
# 0      Missy Elliott  Lose Control (feat. Ciara & Fat Man Scoop)
# 1      Missy Elliott                                     Work It
# 2      Missy Elliott                             Get Ur Freak On
# 3      Missy Elliott             One Minute Man (feat. Ludacris)
# 4      Missy Elliott                             Get Ur Freak On
# ...              ...                                         ...
# 34316          Layla                                  Oh My Love
# 34317        Aayushi                               Diamond Child
# 34318          Jon D                                I Don't Know
# 34319      Big Words                                  The Answer
# 34320      Jon Jason                                Good Feeling
#
#                                   album_uri  \
# 0      spotify:album:6vV5UrXcfyQD1wu4Qo2I9K
# 1      spotify:album:6DeU398qrJ1bLuryetSmup
# 2      spotify:album:6epR3D622KWsnuHye7ApOl
# 3      spotify:album:20t54K6C80QQH7vbcpfJcP
# 4      spotify:album:20t54K6C80QQH7vbcpfJcP
# ...                                     ...
# 34316  spotify:album:4eTl12dc7uQXvgDhtMgW5p
# 34317  spotify:album:5bWtDTwS9llWcnhmgRkav3
# 34318  spotify:album:2KEQtuVl1cYsTYtVRUrNVi
# 34319  spotify:album:5jrsRHRAmetu5e7RRBoxj7
# 34320  spotify:album:2dZ7oVNQBeLlpoUYfbEsJP
#
#                                album_name  danceability  energy  key  \
# 0                            The Cookbook         0.904   0.813    4
# 1                      Under Construction         0.884   0.677    1
# 2                            Respect M.E.         0.794   0.805    0
# 3                   Miss E...So Addictive         0.622   0.669    9
# 4                   Miss E...So Addictive         0.797   0.750    0
# ...                                   ...           ...     ...  ...
# 34316                   Yellow Circles EP         0.434   0.279    8
# 34317                       Diamond Child         0.416   0.394   11
# 34318                               Roots         0.669   0.228    2
# 34319  Hollywood, a Beautiful Coincidence         0.493   0.727    1
# 34320                        Good Feeling         0.509   0.286    8
#
#        loudness  mode  speechiness  ...  valence    tempo  duration_ms  \
# 0        -7.105     0       0.1210  ...    0.810  125.461       226864
# 1        -5.603     1       0.2830  ...    0.584  101.868       263227
# 2        -6.554     1       0.2300  ...    0.658  177.799       236933
# 3        -8.419     1       0.3290  ...    0.570   93.839       252987
# 4        -9.369     1       0.2470  ...    0.740  177.870       211120
# ...         ...   ...          ...  ...      ...      ...          ...
# 34316   -11.947     1       0.0465  ...    0.157  145.264       203676
# 34317    -9.269     1       0.0641  ...    0.131   81.988       237008
# 34318   -12.119     1       0.0690  ...    0.402   83.024       189184
# 34319    -5.031     1       0.2170  ...    0.289   73.259       263680
# 34320   -14.722     1       0.1230  ...    0.259  121.633       194720
#
#        time_signature                                             genres  \
# 0                   4  [dance pop, hip hop, hip pop, neo soul, pop ra...
# 1                   4  [dance pop, hip hop, hip pop, neo soul, pop ra...
# 2                   4  [dance pop, hip hop, hip pop, neo soul, pop ra...
# 3                   4  [dance pop, hip hop, hip pop, neo soul, pop ra...
# 4                   4  [dance pop, hip hop, hip pop, neo soul, pop ra...
# ...               ...                                                ...
# 34316               3                                [indie anthem-folk]
# 34317               4                                                 []
# 34318               4                                      [channel pop]
# 34319               4                                   [australian r&b]
# 34320               4                                                 []
#
#        artist_popularity                             artist_uri  \
# 0                     72  spotify:artist:2wIVse2owClT7go1WT98tk
# 1                     72  spotify:artist:2wIVse2owClT7go1WT98tk
# 2                     72  spotify:artist:2wIVse2owClT7go1WT98tk
# 3                     72  spotify:artist:2wIVse2owClT7go1WT98tk
# 4                     72  spotify:artist:2wIVse2owClT7go1WT98tk
# ...                  ...                                    ...
# 34316                 23  spotify:artist:04BsVprJtIhl2C4fgPEz4W
# 34317                 22  spotify:artist:1r2kTJ27zuaEoXasQT5NDd
# 34318                 41  spotify:artist:5HCypjplgh5uQezvBpOfXN
# 34319                 41  spotify:artist:0sHN89qak07mnug3LVVjzP
# 34320                  2  spotify:artist:77bNdkKYBBmc30CisCA6tE
#
#       track_popularity                             track_uri release_date
# 0                   69  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI   2005-07-04
# 1                   71  spotify:track:3jagJCUbdqhDSPuxP8cAqF   2002-11-11
# 2                   45  spotify:track:3XplJgPz8VjbDzbGwGgZdq   2006-09-04
# 3                   58  spotify:track:0jG92AlXau21qgCQRxGLic   2001-05-14
# 4                   71  spotify:track:6zsk6uF3MxfIeHPlubKBvR   2001-05-14
# ...                ...                                   ...          ...
# 34316               30  spotify:track:0KMrYUEfexgam36li6d9F0   2013-12-02
# 34317                0  spotify:track:1msfqzqHggvi1mlCT4Z7O5   2015-06-16
# 34318               22  spotify:track:3uCHI1gfOUL5j5swEh0TcH   2015-03-28
# 34319               37  spotify:track:0P1oO2gREMYUCoOkzYAyFu   2017-09-22
# 34320               14  spotify:track:4Ri5TTUgjM96tbQZd5Ua7V   2017-08-22
#
# [34321 rows x 23 columns]

# %% [markdown]
# ### Saving resulting data in a CSV file

# %%
# Save final_df to a CSV file
track_data_df.to_csv(r'Data/tracks_features.csv', index = False)
